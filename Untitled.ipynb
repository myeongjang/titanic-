# %% [markdown]
# **Load Data Model and Libraries**

# %% [markdown]
# # Titanic tutorial(Kaggle)
#
# Hello everyone!!!
# I predicted survivors of Titanic. follow the link (https://www.kaggle.com/c/titanic)

# %%
#first import variety tools(pandas, numpy,matplotilib,seaborn)

import pandas as pd
import numpy as np 
from sklearn.preprocessing import LabelEncoder
#Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import sys
from sklearn import preprocessing

# %% [markdown]
# # Load Data

# %%
data_train=pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')
# I prefer to combine because more easy edit features for later
data = data_train.append(data_test)
data.head()# check sample of data list(type pandas)
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %% [markdown]
# The train data and test data involve informations that are Age,Embarked,Fare,Name,Parch(Parents + Child),Passengerld,Pclass,
# Sex, SibSp(Siblings + Spouse),Survived and Ticket number

# %%
data.describe()#This commend show total,mean,standard deviation,minimum and maxmum
# Out:
#                Age         Fare        Parch  PassengerId       Pclass  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027   655.000000     2.294882
# std      14.413493    51.758668     0.865560   378.020061     0.837836
# min       0.170000     0.000000     0.000000     1.000000     1.000000
# 25%      21.000000     7.895800     0.000000   328.000000     2.000000
# 50%      28.000000    14.454200     0.000000   655.000000     3.000000
# 75%      39.000000    31.275000     0.000000   982.000000     3.000000
# max      80.000000   512.329200     9.000000  1309.000000     3.000000
#
#              SibSp    Survived
# count  1309.000000  891.000000
# mean      0.498854    0.383838
# std       1.041658    0.486592
# min       0.000000    0.000000
# 25%       0.000000    0.000000
# 50%       0.000000    0.000000
# 75%       1.000000    1.000000
# max       8.000000    1.000000

# %% [markdown]
# # Data check(null,type and etc..)
# We need to fiil or remove missing data!!!! so first find which is missing!!!

# %%
data.info()# show information of type and etc..
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 417
# Data columns (total 12 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# Fare           1308 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 132.9+ KB

# %%
data.isnull().any()# check which have missing data
# Out:
# Age             True
# Cabin           True
# Embarked        True
# Fare            True
# Name           False
# Parch          False
# PassengerId    False
# Pclass         False
# Sex            False
# SibSp          False
# Survived        True
# Ticket         False
# dtype: bool

# %%
print('Train coloumns with null values:\n',data.isnull().sum())
print('-'*40)
print('Test coloumns with null values:\n',data_test.isnull().sum())
# Out:
# Train coloumns with null values:
#  Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# dtype: int64
# ----------------------------------------
# Test coloumns with null values:
#  PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # Data cleaning & Engineering
# We catch featuers which have missing!! Age,Cabin,Embarked,Fare,Survived
# So we consider how to solve missing data. fill or remove

# %%
"""
PassengerId = data_test['PassengerId']
data = data.drop(['PassengerId'],axis =1)
data_train.head()
"""
# Out:
# "\nPassengerId = data_test['PassengerId']\ndata = data.drop(['PassengerId'],axis =1)\ndata_train.head()\n"

# %%
data_train.loc[data_train['Cabin'].notnull()].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
data['Cabin_type'] = 0
for i in data:
    data['Cabin_type']=data.Cabin.str.extract('([A-Z])')

# %%
data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Cabin_type
# 0       3    male      1       0.0         A/5 21171        NaN
# 1       1  female      1       1.0          PC 17599          C
# 2       3  female      0       1.0  STON/O2. 3101282        NaN
# 3       1  female      1       1.0            113803          C
# 4       3    male      0       0.0            373450        NaN

# %%
data['Cabin_type'] = data['Cabin_type'].fillna('X')

# %%
pd.crosstab(data.Cabin_type,data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6a138720_65ae_11e8_8bd7_909f33093e73row0_col0 {
#             background-color:  #fcfe66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row0_col1 {
#             background-color:  #f7fb66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row1_col0 {
#             background-color:  #fafc66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row1_col1 {
#             background-color:  #d4ea66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row2_col0 {
#             background-color:  #f3f966;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row2_col1 {
#             background-color:  #d4ea66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row3_col0 {
#             background-color:  #fcfe66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row3_col1 {
#             background-color:  #e0f066;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row4_col0 {
#             background-color:  #fcfe66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row4_col1 {
#             background-color:  #e2f066;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row5_col0 {
#             background-color:  #fdfe66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row5_col1 {
#             background-color:  #f6fa66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row6_col0 {
#             background-color:  #ffff66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row6_col1 {
#             background-color:  #fdfe66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row7_col0 {
#             background-color:  #ffff66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row7_col1 {
#             background-color:  #ffff66;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row8_col0 {
#             background-color:  #008066;
#         }    #T_6a138720_65ae_11e8_8bd7_909f33093e73row8_col1 {
#             background-color:  #008066;
#         }</style>
# <table id="T_6a138720_65ae_11e8_8bd7_909f33093e73" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0.0</th>
#         <th class="col_heading level0 col1" >1.0</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Cabin_type</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6a138720_65ae_11e8_8bd7_909f33093e73level0_row0" class="row_heading level0 row0" >A</th>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row0_col0" class="data row0 col0" >8</td>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row0_col1" class="data row0 col1" >7</td>
#     </tr>    <tr>
#         <th id="T_6a138720_65ae_11e8_8bd7_909f33093e73level0_row1" class="row_heading level0 row1" >B</th>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row1_col0" class="data row1 col0" >12</td>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row1_col1" class="data row1 col1" >35</td>
#     </tr>    <tr>
#         <th id="T_6a138720_65ae_11e8_8bd7_909f33093e73level0_row2" class="row_heading level0 row2" >C</th>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row2_col0" class="data row2 col0" >24</td>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row2_col1" class="data row2 col1" >35</td>
#     </tr>    <tr>
#         <th id="T_6a138720_65ae_11e8_8bd7_909f33093e73level0_row3" class="row_heading level0 row3" >D</th>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row3_col0" class="data row3 col0" >8</td>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row3_col1" class="data row3 col1" >25</td>
#     </tr>    <tr>
#         <th id="T_6a138720_65ae_11e8_8bd7_909f33093e73level0_row4" class="row_heading level0 row4" >E</th>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row4_col0" class="data row4 col0" >8</td>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row4_col1" class="data row4 col1" >24</td>
#     </tr>    <tr>
#         <th id="T_6a138720_65ae_11e8_8bd7_909f33093e73level0_row5" class="row_heading level0 row5" >F</th>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row5_col0" class="data row5 col0" >5</td>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row5_col1" class="data row5 col1" >8</td>
#     </tr>    <tr>
#         <th id="T_6a138720_65ae_11e8_8bd7_909f33093e73level0_row6" class="row_heading level0 row6" >G</th>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row6_col0" class="data row6 col0" >2</td>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row6_col1" class="data row6 col1" >2</td>
#     </tr>    <tr>
#         <th id="T_6a138720_65ae_11e8_8bd7_909f33093e73level0_row7" class="row_heading level0 row7" >T</th>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row7_col0" class="data row7 col0" >1</td>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row7_col1" class="data row7 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_6a138720_65ae_11e8_8bd7_909f33093e73level0_row8" class="row_heading level0 row8" >X</th>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row8_col0" class="data row8 col0" >481</td>
#         <td id="T_6a138720_65ae_11e8_8bd7_909f33093e73row8_col1" class="data row8 col1" >206</td>
#     </tr></tbody>
# </table>

# %%
data['Cabin_type'].replace(['A','B','C','D','E','F','G','T','X'],[1,2,3,4,5,6,7,8,0],inplace = True)

# %%
print('Train coloumns with null values:\n',data.isnull().sum())
print('-'*40)
print('Test coloumns with null values:\n',data_test.isnull().sum())
# Out:
# Train coloumns with null values:
#  Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# Cabin_type        0
# dtype: int64
# ----------------------------------------
# Test coloumns with null values:
#  PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(12,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# # Sex with Survived

# %%
data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket  Cabin_type
# 0       3    male      1       0.0         A/5 21171           0
# 1       1  female      1       1.0          PC 17599           3
# 2       3  female      0       1.0  STON/O2. 3101282           0
# 3       1  female      1       1.0            113803           3
# 4       3    male      0       0.0            373450           0

# %%
print(data[['Sex','Survived']].groupby(['Sex'],as_index=False).mean())
print(data[['Sex','Survived']].groupby(['Sex'],as_index=False).count())
print(data.groupby(['Sex','Survived'])['Survived'].count())
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908
#       Sex  Survived
# 0  female       314
# 1    male       577
# Sex     Survived
# female  0.0          81
#         1.0         233
# male    0.0         468
#         1.0         109
# Name: Survived, dtype: int64

# %%
pd.crosstab(data.Sex,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6a138721_65ae_11e8_8bd7_909f33093e73row0_col0 {
#             background-color:  #ffff66;
#         }    #T_6a138721_65ae_11e8_8bd7_909f33093e73row0_col1 {
#             background-color:  #77bb66;
#         }    #T_6a138721_65ae_11e8_8bd7_909f33093e73row0_col2 {
#             background-color:  #ffff66;
#         }    #T_6a138721_65ae_11e8_8bd7_909f33093e73row1_col0 {
#             background-color:  #2c9666;
#         }    #T_6a138721_65ae_11e8_8bd7_909f33093e73row1_col1 {
#             background-color:  #ffff66;
#         }    #T_6a138721_65ae_11e8_8bd7_909f33093e73row1_col2 {
#             background-color:  #8bc566;
#         }    #T_6a138721_65ae_11e8_8bd7_909f33093e73row2_col0 {
#             background-color:  #008066;
#         }    #T_6a138721_65ae_11e8_8bd7_909f33093e73row2_col1 {
#             background-color:  #008066;
#         }    #T_6a138721_65ae_11e8_8bd7_909f33093e73row2_col2 {
#             background-color:  #008066;
#         }</style>
# <table id="T_6a138721_65ae_11e8_8bd7_909f33093e73" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0.0</th>
#         <th class="col_heading level0 col1" >1.0</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6a138721_65ae_11e8_8bd7_909f33093e73level0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_6a138721_65ae_11e8_8bd7_909f33093e73row0_col0" class="data row0 col0" >81</td>
#         <td id="T_6a138721_65ae_11e8_8bd7_909f33093e73row0_col1" class="data row0 col1" >233</td>
#         <td id="T_6a138721_65ae_11e8_8bd7_909f33093e73row0_col2" class="data row0 col2" >314</td>
#     </tr>    <tr>
#         <th id="T_6a138721_65ae_11e8_8bd7_909f33093e73level0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_6a138721_65ae_11e8_8bd7_909f33093e73row1_col0" class="data row1 col0" >468</td>
#         <td id="T_6a138721_65ae_11e8_8bd7_909f33093e73row1_col1" class="data row1 col1" >109</td>
#         <td id="T_6a138721_65ae_11e8_8bd7_909f33093e73row1_col2" class="data row1 col2" >577</td>
#     </tr>    <tr>
#         <th id="T_6a138721_65ae_11e8_8bd7_909f33093e73level0_row2" class="row_heading level0 row2" >All</th>
#         <td id="T_6a138721_65ae_11e8_8bd7_909f33093e73row2_col0" class="data row2 col0" >549</td>
#         <td id="T_6a138721_65ae_11e8_8bd7_909f33093e73row2_col1" class="data row2 col1" >342</td>
#         <td id="T_6a138721_65ae_11e8_8bd7_909f33093e73row2_col2" class="data row2 col2" >891</td>
#     </tr></tbody>
# </table>

# %%
f,ax =plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Survived us dead')
plt.show()

# %% [markdown]
# # Pclass with Survived

# %%
print(data[['Pclass','Survived']].groupby(['Pclass'],as_index=False).mean())
print(data[['Pclass','Survived']].groupby(['Pclass'],as_index=False).count())
print(data.groupby(['Pclass','Survived'])['Survived'].count())
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363
#    Pclass  Survived
# 0       1       216
# 1       2       184
# 2       3       491
# Pclass  Survived
# 1       0.0          80
#         1.0         136
# 2       0.0          97
#         1.0          87
# 3       0.0         372
#         1.0         119
# Name: Survived, dtype: int64

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Survived,data.Sex],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6a138722_65ae_11e8_8bd7_909f33093e73row0_col0 {
#             background-color:  #ffff66;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row0_col1 {
#             background-color:  #ffff66;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row0_col2 {
#             background-color:  #f1f866;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row0_col3 {
#             background-color:  #ffff66;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row1_col0 {
#             background-color:  #a7d366;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row1_col1 {
#             background-color:  #85c266;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row1_col2 {
#             background-color:  #6eb666;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row1_col3 {
#             background-color:  #85c266;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row2_col0 {
#             background-color:  #96cb66;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row2_col1 {
#             background-color:  #a3d166;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row2_col2 {
#             background-color:  #f1f866;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row2_col3 {
#             background-color:  #cfe766;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row3_col0 {
#             background-color:  #cde666;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row3_col1 {
#             background-color:  #f0f866;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row3_col2 {
#             background-color:  #ffff66;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row3_col3 {
#             background-color:  #f7fb66;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row4_col0 {
#             background-color:  #008066;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row4_col1 {
#             background-color:  #008066;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row4_col2 {
#             background-color:  #008066;
#         }    #T_6a138722_65ae_11e8_8bd7_909f33093e73row4_col3 {
#             background-color:  #008066;
#         }</style>
# <table id="T_6a138722_65ae_11e8_8bd7_909f33093e73" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="index_name level1" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6a138722_65ae_11e8_8bd7_909f33093e73level0_row0" class="row_heading level0 row0" rowspan=2>0.0</th>
#         <th id="T_6a138722_65ae_11e8_8bd7_909f33093e73level1_row0" class="row_heading level1 row0" >female</th>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row0_col0" class="data row0 col0" >3</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row0_col1" class="data row0 col1" >6</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row0_col2" class="data row0 col2" >72</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row0_col3" class="data row0 col3" >81</td>
#     </tr>    <tr>
#         <th id="T_6a138722_65ae_11e8_8bd7_909f33093e73level1_row1" class="row_heading level1 row1" >male</th>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row1_col0" class="data row1 col0" >77</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row1_col1" class="data row1 col1" >91</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row1_col2" class="data row1 col2" >300</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row1_col3" class="data row1 col3" >468</td>
#     </tr>    <tr>
#         <th id="T_6a138722_65ae_11e8_8bd7_909f33093e73level0_row2" class="row_heading level0 row2" rowspan=2>1.0</th>
#         <th id="T_6a138722_65ae_11e8_8bd7_909f33093e73level1_row2" class="row_heading level1 row2" >female</th>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row2_col0" class="data row2 col0" >91</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row2_col1" class="data row2 col1" >70</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row2_col2" class="data row2 col2" >72</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row2_col3" class="data row2 col3" >233</td>
#     </tr>    <tr>
#         <th id="T_6a138722_65ae_11e8_8bd7_909f33093e73level1_row3" class="row_heading level1 row3" >male</th>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row3_col0" class="data row3 col0" >45</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row3_col1" class="data row3 col1" >17</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row3_col2" class="data row3 col2" >47</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row3_col3" class="data row3 col3" >109</td>
#     </tr>    <tr>
#         <th id="T_6a138722_65ae_11e8_8bd7_909f33093e73level0_row4" class="row_heading level0 row4" >All</th>
#         <th id="T_6a138722_65ae_11e8_8bd7_909f33093e73level1_row4" class="row_heading level1 row4" ></th>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row4_col0" class="data row4 col0" >216</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row4_col1" class="data row4 col1" >184</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row4_col2" class="data row4 col2" >491</td>
#         <td id="T_6a138722_65ae_11e8_8bd7_909f33093e73row4_col3" class="data row4 col3" >891</td>
#     </tr></tbody>
# </table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# # Per fare

# %%
data.head(20)
# Out:
#      Age Cabin Embarked     Fare  \
# 0   22.0   NaN        S   7.2500
# 1   38.0   C85        C  71.2833
# 2   26.0   NaN        S   7.9250
# 3   35.0  C123        S  53.1000
# 4   35.0   NaN        S   8.0500
# 5    NaN   NaN        Q   8.4583
# 6   54.0   E46        S  51.8625
# 7    2.0   NaN        S  21.0750
# 8   27.0   NaN        S  11.1333
# 9   14.0   NaN        C  30.0708
# 10   4.0    G6        S  16.7000
# 11  58.0  C103        S  26.5500
# 12  20.0   NaN        S   8.0500
# 13  39.0   NaN        S  31.2750
# 14  14.0   NaN        S   7.8542
# 15  55.0   NaN        S  16.0000
# 16   2.0   NaN        Q  29.1250
# 17   NaN   NaN        S  13.0000
# 18  31.0   NaN        S  18.0000
# 19   NaN   NaN        C   7.2250
#
#                                                  Name  Parch  PassengerId  \
# 0                             Braund, Mr. Owen Harris      0            1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                              Heikkinen, Miss. Laina      0            3
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                            Allen, Mr. William Henry      0            5
# 5                                    Moran, Mr. James      0            6
# 6                             McCarthy, Mr. Timothy J      0            7
# 7                      Palsson, Master. Gosta Leonard      1            8
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2            9
# 9                 Nasser, Mrs. Nicholas (Adele Achem)      0           10
# 10                    Sandstrom, Miss. Marguerite Rut      1           11
# 11                           Bonnell, Miss. Elizabeth      0           12
# 12                     Saundercock, Mr. William Henry      0           13
# 13                        Andersson, Mr. Anders Johan      5           14
# 14               Vestrom, Miss. Hulda Amanda Adolfina      0           15
# 15                   Hewlett, Mrs. (Mary D Kingcome)       0           16
# 16                               Rice, Master. Eugene      1           17
# 17                       Williams, Mr. Charles Eugene      0           18
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...      0           19
# 19                            Masselmani, Mrs. Fatima      0           20
#
#     Pclass     Sex  SibSp  Survived            Ticket  Cabin_type
# 0        3    male      1       0.0         A/5 21171           0
# 1        1  female      1       1.0          PC 17599           3
# 2        3  female      0       1.0  STON/O2. 3101282           0
# 3        1  female      1       1.0            113803           3
# 4        3    male      0       0.0            373450           0
# 5        3    male      0       0.0            330877           0
# 6        1    male      0       0.0             17463           5
# 7        3    male      3       0.0            349909           0
# 8        3  female      0       1.0            347742           0
# 9        2  female      1       1.0            237736           0
# 10       3  female      1       1.0           PP 9549           7
# 11       1  female      0       1.0            113783           3
# 12       3    male      0       0.0         A/5. 2151           0
# 13       3    male      1       0.0            347082           0
# 14       3  female      0       0.0            350406           0
# 15       2  female      0       1.0            248706           0
# 16       3    male      4       0.0            382652           0
# 17       2    male      0       1.0            244373           0
# 18       3  female      1       0.0            345763           0
# 19       3  female      0       1.0              2649           0

# %% [markdown]
# # Age--> Continous Feature
#
# I have seperated Age by two way that 'Initial'and 'statistics'
# I tried  combine 'Initial' and 'statistics'

# %% [markdown]
# # First way(Statistics)

# %%
"""
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Yougest Passenger was of:',data['Age'].min(),'Years')
print('Average Passenger was of :',data['Age'].mean(),'Years')
"""
# Out:
# "\nprint('Oldest Passenger was of:',data['Age'].max(),'Years')\nprint('Yougest Passenger was of:',data['Age'].min(),'Years')\nprint('Average Passenger was of :',data['Age'].mean(),'Years')\n"

# %%
"""
age_max = data['Age'].max()
age_min = data['Age'].min()
age_std = data['Age'].std()
age_avg = data['Age'].mean()
age_null_count = data['Age'].isnull().sum()
age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)
data['Age'][np.isnan(data['Age'])] = age_null_random_list
data['Age'] = data['Age'].astype(int)
print(data['Age'].isnull().sum())
data['CategoricalAge'] = pd.cut(data['Age'], 5)
"""
# Out:
# "\nage_max = data['Age'].max()\nage_min = data['Age'].min()\nage_std = data['Age'].std()\nage_avg = data['Age'].mean()\nage_null_count = data['Age'].isnull().sum()\nage_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)\ndata['Age'][np.isnan(data['Age'])] = age_null_random_list\ndata['Age'] = data['Age'].astype(int)\nprint(data['Age'].isnull().sum())\ndata['CategoricalAge'] = pd.cut(data['Age'], 5)\n"

# %%
"""
f,ax =plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue = "Survived",data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survied')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age",hue="Survived",data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()
"""
# Out:
# '\nf,ax =plt.subplots(1,2,figsize=(18,8))\nsns.violinplot("Pclass","Age", hue = "Survived",data=data,split=True,ax=ax[0])\nax[0].set_title(\'Pclass and Age vs Survied\')\nax[0].set_yticks(range(0,110,10))\nsns.violinplot("Sex","Age",hue="Survived",data=data,split=True,ax=ax[1])\nax[1].set_title(\'Sex and Age vs Survived\')\nax[1].set_yticks(range(0,110,10))\nplt.show()\n'

# %%
"""
f,ax =plt.subplots(1,2,figsize=(18,8))
sns.factorplot('Pclass','Survived',hue='CategoricalAge',data=data,ax=ax[0])
sns.factorplot('Sex','Survived',hue='CategoricalAge',data=data,ax=ax[1])
plt.close(2)
plt.show()
"""
# Out:
# "\nf,ax =plt.subplots(1,2,figsize=(18,8))\nsns.factorplot('Pclass','Survived',hue='CategoricalAge',data=data,ax=ax[0])\nsns.factorplot('Sex','Survived',hue='CategoricalAge',data=data,ax=ax[1])\nplt.close(2)\nplt.show()\n"

# %%
f,ax = plt.subplots(1,2,figsize = (18,8))
data[data['Survived'] == 0].Age.plot.hist(ax = ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived = 0')
x1 = list(range(0,85,5))
ax[0].set_xticks(x1)
data[data.Survived ==1].Age.plot.hist(ax = ax[1],color='green',edgecolor='black',bins=20)
ax[1].set_title('Survived = 1')
x2 = list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# # Second Way

# %%
"""data=pd.read_csv('train.csv')"""
# Out:
# "data=pd.read_csv('train.csv')"

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial,data.Sex).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6b240856_65ae_11e8_8bd7_909f33093e73row0_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row0_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row1_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row1_col1 {
#             background-color:  #fefe66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row2_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row2_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row3_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row3_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row4_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row4_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row5_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row5_col1 {
#             background-color:  #fdfe66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row6_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row6_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row7_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row7_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row8_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row8_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row9_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row9_col1 {
#             background-color:  #ebf566;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row10_col0 {
#             background-color:  #008066;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row10_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row11_col0 {
#             background-color:  #fefe66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row11_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row12_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row12_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row13_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row13_col1 {
#             background-color:  #008066;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row14_col0 {
#             background-color:  #3e9e66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row14_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row15_col0 {
#             background-color:  #fefe66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row15_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row16_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row16_col1 {
#             background-color:  #fdfe66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row17_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240856_65ae_11e8_8bd7_909f33093e73row17_col1 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_6b240856_65ae_11e8_8bd7_909f33093e73" >
# <thead>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="col_heading level0 col0" >female</th>
#         <th class="col_heading level0 col1" >male</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Initial</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row0" class="row_heading level0 row0" >Capt</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row0_col0" class="data row0 col0" >0</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row0_col1" class="data row0 col1" >1</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row1" class="row_heading level0 row1" >Col</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row1_col0" class="data row1 col0" >0</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row1_col1" class="data row1 col1" >4</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row2" class="row_heading level0 row2" >Countess</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row2_col0" class="data row2 col0" >1</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row2_col1" class="data row2 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row3" class="row_heading level0 row3" >Don</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row3_col0" class="data row3 col0" >0</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row3_col1" class="data row3 col1" >1</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row4" class="row_heading level0 row4" >Dona</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row4_col0" class="data row4 col0" >1</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row4_col1" class="data row4 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row5" class="row_heading level0 row5" >Dr</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row5_col0" class="data row5 col0" >1</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row5_col1" class="data row5 col1" >7</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row6" class="row_heading level0 row6" >Jonkheer</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row6_col0" class="data row6 col0" >0</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row6_col1" class="data row6 col1" >1</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row7" class="row_heading level0 row7" >Lady</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row7_col0" class="data row7 col0" >1</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row7_col1" class="data row7 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row8" class="row_heading level0 row8" >Major</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row8_col0" class="data row8 col0" >0</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row8_col1" class="data row8 col1" >2</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row9" class="row_heading level0 row9" >Master</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row9_col0" class="data row9 col0" >0</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row9_col1" class="data row9 col1" >61</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row10" class="row_heading level0 row10" >Miss</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row10_col0" class="data row10 col0" >260</td>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row10_col1" class="data row10 col1" >0</td>
#     </tr>    <tr>
#         <th id="T_6b240856_65ae_11e8_8bd7_909f33093e73level0_row11" class="row_heading level0 row11" >Mlle</th>
#         <td id="T_6b240856_65ae_11e8_8bd7_909f33093e73row11_col0" class="data row11 col0" >2</td>

# %%
print(data.groupby('Initial')['Age'].mean())
print(data.groupby('Initial')['Age'].std())
# Out:
# Initial
# Capt        70.000000
# Col         54.000000
# Countess    33.000000
# Don         40.000000
# Dona        39.000000
# Dr          43.571429
# Jonkheer    38.000000
# Lady        48.000000
# Major       48.500000
# Master       5.482642
# Miss        21.774238
# Mlle        24.000000
# Mme         24.000000
# Mr          32.252151
# Mrs         36.994118
# Ms          28.000000
# Rev         41.250000
# Sir         49.000000
# Name: Age, dtype: float64
# Initial
# Capt              NaN
# Col          5.477226
# Countess          NaN
# Don               NaN
# Dona              NaN
# Dr          11.731115
# Jonkheer          NaN
# Lady              NaN
# Major        4.949747
# Master       4.161554
# Miss        12.249077
# Mlle         0.000000
# Mme               NaN
# Mr          12.422089
# Mrs         12.901767
# Ms                NaN
# Rev         12.020815
# Sir               NaN
# Name: Age, dtype: float64

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],['Miss','Miss','Miss','Dr','royal','Mrs','Mrs','Mrs','royal','royal','royal','Mr','Mr','Mrs'],inplace=True)

# %%
data['Surname']=0
for i in data:
    data['Surname']=data.Name.str.extract("\(([^)]+)\)")

# %%
pd.crosstab(data.Surname,data.Sex).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6b240857_65ae_11e8_8bd7_909f33093e73row0_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row0_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row1_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row1_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row2_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row2_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row3_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row3_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row4_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row4_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row5_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row5_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row6_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row6_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row7_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row7_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row8_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row8_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row9_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row9_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row10_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row10_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row11_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row11_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row12_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row12_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row13_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row13_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row14_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row14_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row15_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row15_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row16_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row16_col1 {
#             background-color:  #008066;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row17_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row17_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row18_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row18_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row19_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row19_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row20_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row20_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row21_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row21_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row22_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row22_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row23_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row23_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row24_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row24_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row25_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row25_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row26_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row26_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row27_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row27_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row28_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row28_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row29_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row29_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row30_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row30_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row31_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row31_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row32_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row32_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row33_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row33_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row34_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row34_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row35_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row35_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row36_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row36_col1 {
#             background-color:  #ffff66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row37_col0 {
#             background-color:  #7fbf66;
#         }    #T_6b240857_65ae_11e8_8bd7_909f33093e73row37_col1 {
#             background-color:  #ffff66;
#         }    #T_6b24085

# %%
data['Surname'] = data['Surname'].fillna(0)
data.loc[(data['Surname']  != 0  ),'Surname']= 1

# %%
pd.crosstab(data.Initial,data.Surname,margins = True)
# Out:
# Surname     0    1   All
# Initial
# Dr          7    1     8
# Master     60    1    61
# Miss      260    5   265
# Mr        740   19   759
# Mrs         6  195   201
# royal      15    0    15
# All      1088  221  1309

# %%
pd.crosstab(data.Initial,data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6b240858_65ae_11e8_8bd7_909f33093e73row0_col0 {
#             background-color:  #ffff66;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row0_col1 {
#             background-color:  #fefe66;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row1_col0 {
#             background-color:  #f8fc66;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row1_col1 {
#             background-color:  #d6eb66;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row2_col0 {
#             background-color:  #e1f066;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row2_col1 {
#             background-color:  #008066;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row3_col0 {
#             background-color:  #008066;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row3_col1 {
#             background-color:  #61b066;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row4_col0 {
#             background-color:  #f2f866;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row4_col1 {
#             background-color:  #3b9d66;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row5_col0 {
#             background-color:  #fdfe66;
#         }    #T_6b240858_65ae_11e8_8bd7_909f33093e73row5_col1 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_6b240858_65ae_11e8_8bd7_909f33093e73" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0.0</th>
#         <th class="col_heading level0 col1" >1.0</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Initial</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6b240858_65ae_11e8_8bd7_909f33093e73level0_row0" class="row_heading level0 row0" >Dr</th>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row0_col0" class="data row0 col0" >4</td>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row0_col1" class="data row0 col1" >3</td>
#     </tr>    <tr>
#         <th id="T_6b240858_65ae_11e8_8bd7_909f33093e73level0_row1" class="row_heading level0 row1" >Master</th>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row1_col0" class="data row1 col0" >17</td>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row1_col1" class="data row1 col1" >23</td>
#     </tr>    <tr>
#         <th id="T_6b240858_65ae_11e8_8bd7_909f33093e73level0_row2" class="row_heading level0 row2" >Miss</th>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row2_col0" class="data row2 col0" >55</td>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row2_col1" class="data row2 col1" >131</td>
#     </tr>    <tr>
#         <th id="T_6b240858_65ae_11e8_8bd7_909f33093e73level0_row3" class="row_heading level0 row3" >Mr</th>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row3_col0" class="data row3 col0" >437</td>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row3_col1" class="data row3 col1" >82</td>
#     </tr>    <tr>
#         <th id="T_6b240858_65ae_11e8_8bd7_909f33093e73level0_row4" class="row_heading level0 row4" >Mrs</th>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row4_col0" class="data row4 col0" >27</td>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row4_col1" class="data row4 col1" >101</td>
#     </tr>    <tr>
#         <th id="T_6b240858_65ae_11e8_8bd7_909f33093e73level0_row5" class="row_heading level0 row5" >royal</th>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row5_col0" class="data row5 col0" >9</td>
#         <td id="T_6b240858_65ae_11e8_8bd7_909f33093e73row5_col1" class="data row5 col1" >2</td>
#     </tr></tbody>
# </table>

# %%
Ini = ['Master','Miss','Mr','Mrs','Dr','royal']
def seperate(x):
    i = data.loc[(data.Initial == str(x))]
    age_max = i['Age'].max()
    age_min = i['Age'].min()
    age_std = i['Age'].std()
    age_avg = i['Age'].mean()

    age_null_count = i['Age'].isnull().sum()
    age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)
    for number in age_null_random_list:
        data.loc[(data.Age.isnull())&(data.Initial ==x),'Age']=number
     
    return data
for i in Ini:
    seperate(i)

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f,ax =plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue = "Survived",data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survied')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age",hue="Survived",data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
f,ax = plt.subplots(1,2,figsize = (18,8))
data[data['Survived'] == 0].Age.plot.hist(ax = ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived = 0')
x1 = list(range(0,85,5))
ax[0].set_xticks(x1)
data[data.Survived ==1].Age.plot.hist(ax = ax[1],color='green',edgecolor='black',bins=20)
ax[1].set_title('Survived = 1')
x2 = list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived', col = 'Initial',data=data)
plt.show()

# %% [markdown]
# # Embarked-->Categorical Value

# %%
pd.crosstab([data['Embarked'],data['Pclass']],[data['Sex'],data['Survived']],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6cc31242_65ae_11e8_8bd7_909f33093e73row0_col0 {
#             background-color:  #fcfe66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row0_col1 {
#             background-color:  #d2e866;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row0_col2 {
#             background-color:  #f2f866;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row0_col3 {
#             background-color:  #d8ec66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row0_col4 {
#             background-color:  #e8f466;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row1_col0 {
#             background-color:  #ffff66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row1_col1 {
#             background-color:  #f9fc66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row1_col2 {
#             background-color:  #fcfe66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row1_col3 {
#             background-color:  #fbfd66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row1_col4 {
#             background-color:  #fbfd66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row2_col0 {
#             background-color:  #e6f266;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row2_col1 {
#             background-color:  #f0f866;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row2_col2 {
#             background-color:  #eef666;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row2_col3 {
#             background-color:  #e8f466;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row2_col4 {
#             background-color:  #edf666;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row3_col0 {
#             background-color:  #ffff66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row3_col1 {
#             background-color:  #ffff66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row3_col2 {
#             background-color:  #ffff66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row3_col3 {
#             background-color:  #ffff66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row3_col4 {
#             background-color:  #ffff66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row4_col0 {
#             background-color:  #ffff66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row4_col1 {
#             background-color:  #fefe66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row4_col2 {
#             background-color:  #ffff66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row4_col3 {
#             background-color:  #ffff66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row4_col4 {
#             background-color:  #ffff66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row5_col0 {
#             background-color:  #e3f166;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row5_col1 {
#             background-color:  #e6f266;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row5_col2 {
#             background-color:  #ecf666;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row5_col3 {
#             background-color:  #f8fc66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row5_col4 {
#             background-color:  #ebf566;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row6_col0 {
#             background-color:  #f9fc66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row6_col1 {
#             background-color:  #cde666;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row6_col2 {
#             background-color:  #e4f266;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row6_col3 {
#             background-color:  #bede66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row6_col4 {
#             background-color:  #dbed66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row7_col0 {
#             background-color:  #edf666;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row7_col1 {
#             background-color:  #bdde66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row7_col2 {
#             background-color:  #d3e966;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row7_col3 {
#             background-color:  #dcee66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row7_col4 {
#             background-color:  #d1e866;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row8_col0 {
#             background-color:  #52a866;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row8_col1 {
#             background-color:  #dcee66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row8_col2 {
#             background-color:  #81c066;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row8_col3 {
#             background-color:  #b0d866;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row8_col4 {
#             background-color:  #9acc66;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row9_col0 {
#             background-color:  #008066;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row9_col1 {
#             background-color:  #008066;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row9_col2 {
#             background-color:  #008066;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row9_col3 {
#             background-color:  #008066;
#         }    #T_6cc31242_65ae_11e8_8bd7_909f33093e73row9_col4 {
#             background-color:  #008066;
#         }</style>
# <table id="T_6cc31242_65ae_11e8_8bd7_909f33093e73" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Sex</th>
#         <th class="col_heading level0 col0" colspan=2>female</th>
#         <th class="col_heading level0 col2" colspan=2>male</th>
#         <th class="col_heading level0 col4" >All</th>
#     </tr>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level1" >Survived</th>
#         <th class="col_heading level1 col0" >0.0</th>
#         <th class="col_heading level1 col1" >1.0</th>
#         <th class="col_heading level1 col2" >0.0</th>
#         <th class="col_heading level1 col3" >1.0</th>
#         <th class="col_heading level1 col4" ></th>
#     </tr>    <tr>
#         <th class="index_name level0" >Embarked</th>
#         <th class="index_name level1" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6cc31242_65ae_11e8_8bd7_909f33093e73level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#         <th id="T_6cc31242_65ae_11e8_8bd7_909f33093e73level1_row0" class="row_heading level1 row0" >1</th>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row0_col0" class="data row0 col0" >1</td>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row0_col1" class="data row0 col1" >42</td>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row0_col2" class="data row0 col2" >25</td>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row0_col3" class="data row0 col3" >17</td>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row0_col4" class="data row0 col4" >85</td>
#     </tr>    <tr>
#         <th id="T_6cc31242_65ae_11e8_8bd7_909f33093e73level1_row1" class="row_heading level1 row1" >2</th>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row1_col0" class="data row1 col0" >0</td>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row1_col1" class="data row1 col1" >7</td>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row1_col2" class="data row1 col2" >8</td>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row1_col3" class="data row1 col3" >2</td>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row1_col4" class="data row1 col4" >17</td>
#     </tr>    <tr>
#         <th id="T_6cc31242_65ae_11e8_8bd7_909f33093e73level1_row2" class="row_heading level1 row2" >3</th>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row2_col0" class="data row2 col0" >8</td>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row2_col1" class="data row2 col1" >15</td>
#         <td id="T_6cc31242_65ae_11e8_8bd7_909f33093e73row2_col2

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax = plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue = 'Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue = 'Sex',col='Embarked',data=data)
plt.show()

# %%
data['Embarked'].fillna('S', inplace =True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# # FamilySize and Alone

# %%
data['Alone'] = 0
data['FamilySize'] = data['Parch']+ data['SibSp']+1
data.loc[(data['FamilySize']==1),'Alone'] = 1

# %%
f,ax = plt.subplots(1,2,figsize=(20,8))
sns.barplot(data.FamilySize,data.Survived, data=data,ax = ax[0])
ax[0].set_title('FamilySize vs Survived')
sns.factorplot('FamilySize','Survived',data = data,ax=ax[1])
ax[1].set_title('FamilySize vs Survived')
plt.close(2)
plt.show()

# %%
sns.factorplot('FamilySize','Survived',data = data,hue = 'Sex',col = 'Pclass')
plt.show()

# %%
data['Peers'] =  data.groupby('Ticket')['Ticket'].transform('size')

# %%
data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket  Cabin_type Initial  \
# 0       3    male      1       0.0         A/5 21171           0      Mr
# 1       1  female      1       1.0          PC 17599           3     Mrs
# 2       3  female      0       1.0  STON/O2. 3101282           0    Miss
# 3       1  female      1       1.0            113803           3     Mrs
# 4       3    male      0       0.0            373450           0      Mr
#
#    Surname  Alone  FamilySize  Peers
# 0        0      0           2      1
# 1        1      0           2      2
# 2        0      1           1      1
# 3        1      0           2      2
# 4        0      1           1      1

# %%
f,ax = plt.subplots(1,2,figsize=(20,8))
sns.barplot(data.Peers,data.Survived, data=data,ax = ax[0])
ax[0].set_title('Peers vs Survived')
sns.factorplot('Peers','Survived',data = data,ax=ax[1])
ax[1].set_title('Peers vs Survived')
plt.close(2)
plt.show()

# %%
sns.factorplot('Peers','Survived',data = data,hue = 'Sex',col = 'Pclass')
plt.show()

# %%
data['max'] = 0
data['max'] =  data.groupby('Ticket')[['FamilySize','Peers']].transform('max')
data.head()
data.loc[(data['Peers']==7)]
# Out:
#       Age            Cabin Embarked      Fare  \
# 13   39.0              NaN        S   31.2750
# 25   38.0              NaN        S   31.3875
# 50    7.0              NaN        S   39.6875
# 72   21.0              NaN        S   73.5000
# 119   2.0              NaN        S   31.2750
# 120  21.0              NaN        S   73.5000
# 164   1.0              NaN        S   39.6875
# 182   9.0              NaN        S   31.3875
# 233   5.0              NaN        S   31.3875
# 261   3.0              NaN        S   31.3875
# 266  16.0              NaN        S   39.6875
# 311  18.0  B57 B59 B63 B66        C  262.3750
# 385  18.0              NaN        S   73.5000
# 541   9.0              NaN        S   31.2750
# 542  11.0              NaN        S   31.2750
# 610  39.0              NaN        S   31.2750
# 638  41.0              NaN        S   39.6875
# 655  24.0              NaN        S   73.5000
# 665  32.0              NaN        S   73.5000
# 686  14.0              NaN        S   39.6875
# 742  21.0  B57 B59 B63 B66        C  262.3750
# 813   6.0              NaN        S   31.2750
# 824   2.0              NaN        S   39.6875
# 850   4.0              NaN        S   31.2750
# 24   48.0  B57 B59 B63 B66        C  262.3750
# 59   36.0              B61        C  262.3750
# 64   13.0  B57 B59 B63 B66        C  262.3750
# 142  61.0  B57 B59 B63 B66        C  262.3750
# 154  13.0              NaN        S   31.3875
# 174  40.0              NaN        S   31.3875
# 212  17.0              NaN        S   73.5000
# 352  18.0              NaN        S   73.5000
# 367  22.0              NaN        S   39.6875
# 375  45.0              NaN        C  262.3750
# 379   5.0              NaN        S   31.3875
#
#                                                   Name  Parch  PassengerId  \
# 13                         Andersson, Mr. Anders Johan      5           14
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5           26
# 50                          Panula, Master. Juha Niilo      1           51
# 72                                Hood, Mr. Ambrose Jr      0           73
# 119                  Andersson, Miss. Ellis Anna Maria      2          120
# 120                        Hickman, Mr. Stanley George      0          121
# 164                       Panula, Master. Eino Viljami      1          165
# 182              Asplund, Master. Clarence Gustaf Hugo      2          183
# 233                     Asplund, Miss. Lillian Gertrud      2          234
# 261                  Asplund, Master. Edvin Rojj Felix      2          262
# 266                          Panula, Mr. Ernesti Arvid      1          267
# 311                         Ryerson, Miss. Emily Borie      2          312
# 385                          Davies, Mr. Charles Henry      0          386
# 541               Andersson, Miss. Ingeborg Constanzia      2          542
# 542                  Andersson, Miss. Sigrid Elisabeth      2          543
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...      5          611
# 638             Panula, Mrs. Juha (Maria Emilia Ojala)      5          639
# 655                          Hickman, Mr. Leonard Mark      0          656
# 665                                 Hickman, Mr. Lewis      0          666
# 686                           Panula, Mr. Jaako Arnold      1          687
# 742              Ryerson, Miss. Susan Parker "Suzette"      2          743
# 813                 Andersson, Miss. Ebba Iris Alfrida      2          814
# 824                       Panula, Master. Urho Abraham      1          825
# 850            Andersson, Master. Sigvard Harald Elias      2          851
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)      3          916
# 59                         Chaudanson, Miss. Victorine      0          951
# 64                         Ryerson, Master. John Borie      2          956
# 142                         Ryerson, Mr. Arthur Larned      3         1034
# 154                       Asplund, Master. Filip Oscar      2         1046
# 174         Asplund, Mr. Carl Oscar Vilhelm Gustafsson      5         1066
# 212                          Deacon, Mr. Percy William      0         1104
# 352                                Dibden, Mr. William      0         1244
# 367       Riihivouri, Miss. Susanna Juhantytar Sanni""      0         1259
# 375                           Bowen, Miss. Grace Scott      0         1267
# 379                        Asplund, Master. Carl Edgar      2         1271
#
#      Pclass     Sex  SibSp  Survived        Ticket  Cabin_type Initial  \
# 13        3    male      1       0.0        347082           0      Mr
# 25        3  female      1       1.0        347077           0     Mrs
# 50        3    male      4       0.0       3101295           0  Master
# 72        2    male      0       0.0  S.O.C. 14879           0      Mr
# 119       3  female      4       0.0        347082           0    Miss
# 120       2    male      2       0.0  S.O.C. 14879           0      Mr
# 164       3    male      4       0.0       3101295           0  Master
# 182       3    male      4       0.0        347077           0  Master
# 233       3  female      4       1.0        347077           0    Miss
# 261       3    male      4       1.0        347077           0  Master
# 266       3    male      4       0.0       3101295           0      Mr
# 311       1  female      2       1.0      PC 17608           2    Miss
# 385       2    male      0       0.0  S.O.C. 14879           0      Mr
# 541       3  female      4       0.0        347082           0    Miss
# 542       3  female      4       0.0        347082           0    Miss
# 610       3  female      1       0.0        347082           0     Mrs
# 638       3  female      0       0.0       3101295           0     Mrs
# 655       2    male      2       0.0  S.O.C. 14879           0      Mr
# 665       2    male      2       0.0  S.O.C. 14879           0      Mr
# 686       3    male      4       0.0       3101295           0      Mr
# 742       1  female      2       1.0      PC 17608           2    Miss
# 813       3  female      4       0.0        347082           0    Miss
# 824       3    male      4       0.0       3101295           0  Master
# 850       3    male      4       0.0        347082           0  Master
# 24        1  female      1       NaN      PC 17608           2     Mrs
# 59        1  female      0       NaN      PC 17608           2    Miss
# 64        1    male      2       NaN      PC 17608           2  Master
# 142       1    male      1       NaN      PC 17608           2      Mr
# 154       3    male      4       NaN        347077           0  Master
# 174       3    male      1       NaN        347077           0      Mr
# 212       2    male      0       NaN  S.O.C. 14879           0      Mr
# 352       2    male      0       NaN  S.O.C. 14879           0      Mr
# 367       3  female      0       NaN       3101295           0    Miss
# 375       1  female      0       NaN      PC 17608           0    Miss
# 379       3    male      4       NaN        347077           0  Master
#
#      Surname  Alone  FamilySize  Peers  max
# 13         0      0           7      7    7
# 25         1      0           7      7    7
# 50         0      0           6      7    6
# 72         0      1           1      7    3
# 119        0      0           7      7    7
# 120        0      0           3      7    3
# 164        0      0           6      7    6
# 182        0      0           7      7    7
# 233        0      0           7      7    7
# 261        0      0           7      7    7
# 266        0      0           6      7    6
# 311        0      0           5      7    5
# 385        0      1           1      7    3
# 541        0      0           7      7    7
# 542        0      0           7      7    7
# 610        1      0           7      7    7
# 638        1      0           6      7    6
# 655        0      0           3      7    3
# 665        0      0           3      7    3
# 686        0      0           6      7    6
# 742        0      0           5      7    5
# 813        0      0           7      7    7
# 824        0      0           6      7    6
# 850        0      0           7      7    7
# 24         1      0           5      7    5
# 59         0      1           1      7    5
# 64         0      0           5      7    5
# 142        0      0           5      7    5
# 154        0      0           7      7    7
# 174        0      0           7      7    7
# 212        0      1           1      7    3
# 352        0      1           1      7    3
# 367        0      1           1      7    6
# 375        0      1           1      7    5
# 379        0      0           7      7    7

# %%
data['Group']=data['FamilySize']/data['max']

# %%
data['Fare'].fillna(data['Fare'].median(), inplace = True)

# %%
data["per_fare"] = data["Fare"]/ (data["max"])

# %%
data['Fare'].isnull().any()
# Out:
# False

# %%
data['Fare'].fillna(data['Fare'].median(), inplace = True)
data['FareBin'] = pd.qcut(data['Fare'], 5)

label = LabelEncoder()
data['FareBin_Code'] = label.fit_transform(data['FareBin'])

# %%
data.loc[(data['Group'] < 1),'Group'] = 0

# %%
pd.crosstab([data['Group'],data['Sex']],data['Survived'],margins = True).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
#     #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row0_col0 {
#             background-color:  #ffff66;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row0_col1 {
#             background-color:  #f2f866;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row0_col2 {
#             background-color:  #fdfe66;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row1_col0 {
#             background-color:  #fbfd66;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row1_col1 {
#             background-color:  #ffff66;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row1_col2 {
#             background-color:  #ffff66;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row2_col0 {
#             background-color:  #dbed66;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row2_col1 {
#             background-color:  #64b266;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row2_col2 {
#             background-color:  #b0d866;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row3_col0 {
#             background-color:  #2b9566;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row3_col1 {
#             background-color:  #b4da66;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row3_col2 {
#             background-color:  #60b066;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row4_col0 {
#             background-color:  #008066;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row4_col1 {
#             background-color:  #008066;
#         }    #T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row4_col2 {
#             background-color:  #008066;
#         }</style>
# <table id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0.0</th>
#         <th class="col_heading level0 col1" >1.0</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Group</th>
#         <th class="index_name level1" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73level0_row0" class="row_heading level0 row0" rowspan=2>0.0</th>
#         <th id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73level1_row0" class="row_heading level1 row0" >female</th>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row0_col0" class="data row0 col0" >2</td>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row0_col1" class="data row0 col1" >23</td>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row0_col2" class="data row0 col2" >25</td>
#     </tr>    <tr>
#         <th id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73level1_row1" class="row_heading level1 row1" >male</th>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row1_col0" class="data row1 col0" >11</td>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row1_col1" class="data row1 col1" >5</td>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row1_col2" class="data row1 col2" >16</td>
#     </tr>    <tr>
#         <th id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73level0_row2" class="row_heading level0 row2" rowspan=2>1.0</th>
#         <th id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73level1_row2" class="row_heading level1 row2" >female</th>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row2_col0" class="data row2 col0" >79</td>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row2_col1" class="data row2 col1" >210</td>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row2_col2" class="data row2 col2" >289</td>
#     </tr>    <tr>
#         <th id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73level1_row3" class="row_heading level1 row3" >male</th>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row3_col0" class="data row3 col0" >457</td>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row3_col1" class="data row3 col1" >104</td>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row3_col2" class="data row3 col2" >561</td>
#     </tr>    <tr>
#         <th id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73level0_row4" class="row_heading level0 row4" >All</th>
#         <th id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73level1_row4" class="row_heading level1 row4" ></th>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row4_col0" class="data row4 col0" >549</td>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row4_col1" class="data row4 col1" >342</td>
#         <td id="T_6fb7faf8_65ae_11e8_8bd7_909f33093e73row4_col2" class="data row4 col2" >891</td>
#     </tr></tbody>
# </table>

# %%
f,ax = plt.subplots(1,2,figsize=(20,8))
sns.barplot(data.Group,data.Survived, data=data,ax = ax[0])
ax[0].set_title('Group vs Survived')
sns.factorplot('Group','Survived',data = data,ax=ax[1])
ax[1].set_title('Group vs Survived')
plt.close(2)
plt.show()

# %%
data['Sex'].replace(['male','female'],[1,0],inplace = True)
lab_enc = preprocessing.LabelEncoder()
data['Initial'] =  lab_enc.fit_transform(data['Initial'])

# %%
data.isnull().sum()
# Out:
# Age                0
# Cabin           1014
# Embarked           0
# Fare               0
# Name               0
# Parch              0
# PassengerId        0
# Pclass             0
# Sex                0
# SibSp              0
# Survived         418
# Ticket             0
# Cabin_type         0
# Initial            0
# Surname            0
# Alone              0
# FamilySize         0
# Peers              0
# max                0
# Group              0
# per_fare           0
# FareBin            0
# FareBin_Code       0
# dtype: int64

# %%
data['Age']= data['Age'].fillna(0)

data.isnull().any()
# Out:
# Age             False
# Cabin            True
# Embarked        False
# Fare            False
# Name            False
# Parch           False
# PassengerId     False
# Pclass          False
# Sex             False
# SibSp           False
# Survived         True
# Ticket          False
# Cabin_type      False
# Initial         False
# Surname         False
# Alone           False
# FamilySize      False
# Peers           False
# max             False
# Group           False
# per_fare        False
# FareBin         False
# FareBin_Code    False
# dtype: bool

# %%
data['Age_type'] = 0
data.loc[(data.Age == 0),'Age_type'] = 0
data.loc[(data.Age >0) & (data.Age < 8),'Age_type'] = 1
data.loc[(data.Age >=8) & (data.Age < 20),'Age_type'] = 2
data.loc[(data.Age >=20) & (data.Age < 50),'Age_type'] = 3
data.loc[(data.Age >=50 ),'Age_type'] = 4
data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass  Sex  SibSp    ...     Surname Alone  FamilySize  Peers  max  Group  \
# 0       3    1      1    ...           0     0           2      1    2    1.0
# 1       1    0      1    ...           1     0           2      2    2    1.0
# 2       3    0      0    ...           0     1           1      1    1    1.0
# 3       1    0      1    ...           1     0           2      2    2    1.0
# 4       3    1      0    ...           0     1           1      1    1    1.0
#
#    per_fare            FareBin  FareBin_Code  Age_type
# 0   3.62500    (-0.001, 7.854]             0         3
# 1  35.64165  (41.579, 512.329]             4         3
# 2   7.92500      (7.854, 10.5]             1         3
# 3  26.55000  (41.579, 512.329]             4         3
# 4   8.05000      (7.854, 10.5]             1         3
#
# [5 rows x 24 columns]

# %%
data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass  Sex  SibSp    ...     Surname Alone  FamilySize  Peers  max  Group  \
# 0       3    1      1    ...           0     0           2      1    2    1.0
# 1       1    0      1    ...           1     0           2      2    2    1.0
# 2       3    0      0    ...           0     1           1      1    1    1.0
# 3       1    0      1    ...           1     0           2      2    2    1.0
# 4       3    1      0    ...           0     1           1      1    1    1.0
#
#    per_fare            FareBin  FareBin_Code  Age_type
# 0   3.62500    (-0.001, 7.854]             0         3
# 1  35.64165  (41.579, 512.329]             4         3
# 2   7.92500      (7.854, 10.5]             1         3
# 3  26.55000  (41.579, 512.329]             4         3
# 4   8.05000      (7.854, 10.5]             1         3
#
# [5 rows x 24 columns]

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
data['Age_type'].value_counts().plot.pie(explode = [0.2,0,0,0],autopct = '%1.1f%%',ax = ax[0],shadow = True)
ax[0].set_title = ('Age ratio')
ax[0].set_ylabel('')
sns.countplot('Age_type',data = data , ax= ax[1])
ax[1].set_title = ('Total Age_type')
plt.show()

# %%
print(data[["Age_type","Survived"]].groupby("Age_type").mean())
print(data[["Age_type","Survived"]].groupby("Age_type").std())
# Out:
#           Survived
# Age_type
# 1         0.666667
# 2         0.446667
# 3         0.346405
# 4         0.360000
#           Survived
# Age_type
# 1         0.475831
# 2         0.498813
# 3         0.476213
# 4         0.483232

# %%
data["Name_length"] =  data["Name"].apply(len)

# %%
pd.crosstab(data.Initial,data.Surname,margins = True)
# Out:
# Surname     0    1   All
# Initial
# 0           7    1     8
# 1          60    1    61
# 2         260    5   265
# 3         740   19   759
# 4           6  195   201
# 5          15    0    15
# All      1088  221  1309

# %%
train_index = data_train.shape[0]

# %%
data['Last_name'] = data['Name'].apply(lambda x: str.split(x,",")[0])

# %%
train_size = len(data_train)
fare_df = data.loc[data['FamilySize']>1, ["Last_name", "Fare", "FamilySize"]].iloc[:train_size]
fare_diff = (((fare_df.groupby(['Last_name', 'FamilySize']).max() 
 - fare_df.groupby(['Last_name', 'FamilySize']).min())!=0).sum()/train_size * 100)
print(fare_df)
print(("Percentage of families with different fares is: %.1f" %(fare_diff.values)) + '%')
# Out:
#             Last_name      Fare  FamilySize
# 0              Braund    7.2500           2
# 1             Cumings   71.2833           2
# 3            Futrelle   53.1000           2
# 7             Palsson   21.0750           5
# 8             Johnson   11.1333           3
# 9              Nasser   30.0708           2
# 10          Sandstrom   16.7000           3
# 13          Andersson   31.2750           7
# 16               Rice   29.1250           6
# 18      Vander Planke   18.0000           2
# 24            Palsson   21.0750           5
# 25            Asplund   31.3875           7
# 27            Fortune  263.0000           6
# 31            Spencer  146.5208           2
# 34              Meyer   82.1708           2
# 35          Holverson   52.0000           2
# 38      Vander Planke   18.0000           3
# 39      Nicola-Yarred   11.2417           2
# 40              Ahlin    9.4750           2
# 41             Turpin   21.0000           2
# 43            Laroche   41.5792           4
# 46             Lennon   15.5000           2
# 48             Samaan   21.6792           3
# 49     Arnold-Franchi   17.8000           2
# 50             Panula   39.6875           6
# 52             Harper   76.7292           2
# 53         Faunthorpe   26.0000           2
# 54              Ostby   61.9792           2
# 58               West   27.7500           4
# 59            Goodwin   46.9000           8
# ..                ...       ...         ...
# 353            Herman   65.0000           4
# 354              Dean   20.5750           4
# 356             Brown   51.4792           3
# 359           Lindell   15.5500           2
# 360              Sage   69.5500          11
# 361            Mallet   37.0042           3
# 364            Harder   55.4417           2
# 365              Sage   69.5500          11
# 366             Caram   14.4583           2
# 368            Gibson   59.4000           2
# 370             Giles   11.5000           2
# 374             Dodge   81.8583           3
# 376              Kink    8.6625           3
# 379           Asplund   31.3875           7
# 383           McNamee   16.1000           2
# 385            Herman   65.0000           4
# 389           Palsson   21.0750           5
# 391             Lines   39.4000           2
# 392            Abbott   20.2500           3
# 394     Kink-Heilmann   22.0250           5
# 395             Smith   60.0000           2
# 397  Frolicher-Stehli   79.2000           3
# 401              Gale   21.0000           2
# 402            Gibson   59.4000           2
# 404        Frauenthal   27.7208           2
# 406              Ware   10.5000           2
# 407           Widener  211.5000           3
# 409           Peacock   13.7750           3
# 411           Minahan   90.0000           2
# 417             Peter   22.3583           3
#
# [519 rows x 3 columns]
# Percentage of families with different fares is: 1.7%

# %%
fare_diff = (((fare_df.groupby(['Last_name', 'FamilySize']).max() 
 - fare_df.groupby(['Last_name', 'FamilySize']).min())!=0))
fare_diff.head()
# Out:
#                        Fare
# Last_name FamilySize
# Abbott    3           False
# Abelson   2           False
# Ahlin     2           False
# Aks       2           False
# Allison   4           False

# %%
train_temp_df = data.iloc[:train_size]
family_df_grpby = train_temp_df[train_temp_df['FamilySize']>1][
    ['Last_name', 'Fare', 'FamilySize', 'Survived']].groupby(['Last_name','Fare'])
for i,d in family_df_grpby:
    print((d),len(d))
# Out:
#     Last_name   Fare  FamilySize  Survived
# 279    Abbott  20.25           3       1.0
# 746    Abbott  20.25           3       0.0 2
#     Last_name  Fare  FamilySize  Survived
# 308   Abelson  24.0           2       0.0
# 874   Abelson  24.0           2       1.0 2
#    Last_name   Fare  FamilySize  Survived
# 40     Ahlin  9.475           2       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 855       Aks  9.35           2       1.0 1
#     Last_name    Fare  FamilySize  Survived
# 297   Allison  151.55           4       0.0
# 305   Allison  151.55           4       1.0
# 498   Allison  151.55           4       0.0 3
#            Last_name    Fare  FamilySize  Survived
# 192  Andersen-Jensen  7.8542           2       1.0 1
#     Last_name   Fare  FamilySize  Survived
# 68  Andersson  7.925           7       1.0 1
#      Last_name    Fare  FamilySize  Survived
# 13   Andersson  31.275           7       0.0
# 119  Andersson  31.275           7       0.0
# 541  Andersson  31.275           7       0.0
# 542  Andersson  31.275           7       0.0
# 610  Andersson  31.275           7       0.0
# 813  Andersson  31.275           7       0.0
# 850  Andersson  31.275           7       0.0 7
#     Last_name     Fare  FamilySize  Survived
# 275   Andrews  77.9583           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 518     Angle  26.0           2       1.0 1
#     Last_name     Fare  FamilySize  Survived
# 571  Appleton  51.4792           3       1.0 1
#           Last_name  Fare  FamilySize  Survived
# 49   Arnold-Franchi  17.8           2       0.0
# 353  Arnold-Franchi  17.8           2       0.0 2
#     Last_name     Fare  FamilySize  Survived
# 25    Asplund  31.3875           7       1.0
# 182   Asplund  31.3875           7       0.0
# 233   Asplund  31.3875           7       1.0
# 261   Asplund  31.3875           7       1.0 4
#     Last_name     Fare  FamilySize  Survived
# 700     Astor  227.525           2       1.0 1
#      Last_name   Fare  FamilySize  Survived
# 85   Backstrom  15.85           4       1.0
# 206  Backstrom  15.85           2       0.0 2
#     Last_name     Fare  FamilySize  Survived
# 448   Baclini  19.2583           4       1.0
# 469   Baclini  19.2583           4       1.0
# 644   Baclini  19.2583           4       1.0
# 858   Baclini  19.2583           4       1.0 4
#     Last_name     Fare  FamilySize  Survived
# 362   Barbara  14.4542           2       0.0
# 702   Barbara  14.4542           2       0.0 2
#     Last_name      Fare  FamilySize  Survived
# 118    Baxter  247.5208           2       0.0
# 299    Baxter  247.5208           2       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 543     Beane  26.0           2       1.0
# 546     Beane  26.0           2       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 183    Becker  39.0           4       1.0
# 618    Becker  39.0           4       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 248  Beckwith  52.5542           3       1.0
# 871  Beckwith  52.5542           3       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 291    Bishop  91.0792           2       1.0
# 484    Bishop  91.0792           2       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 140    Boulos  15.2458           3       0.0
# 852    Boulos  15.2458           3       0.0 2
#     Last_name  Fare  FamilySize  Survived
# 593    Bourke  7.75           3       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 188    Bourke  15.5           3       0.0
# 657    Bourke  15.5           3       0.0 2
#     Last_name  Fare  FamilySize  Survived
# 356  Bowerman  55.0           2       1.0 1
#     Last_name    Fare  FamilySize  Survived
# 477    Braund  7.0458           2       0.0 1
#   Last_name  Fare  FamilySize  Survived
# 0    Braund  7.25           2       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 670     Brown  39.0           3       1.0
# 684     Brown  39.0           3       0.0 2
#     Last_name  Fare  FamilySize  Survived
# 728     Bryhl  26.0           2       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 78   Caldwell  29.0           3       1.0
# 323  Caldwell  29.0           3       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 578     Caram  14.4583           2       0.0 1
#     Last_name      Fare  FamilySize  Survived
# 679   Cardeza  512.3292           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 249    Carter  26.0           2       0.0
# 854    Carter  26.0           2       0.0 2
#     Last_name   Fare  FamilySize  Survived
# 390    Carter  120.0           4       1.0
# 435    Carter  120.0           4       1.0
# 763    Carter  120.0           4       1.0
# 802    Carter  120.0           4       1.0 4
#      Last_name   Fare  FamilySize  Survived
# 741  Cavendish  78.85           2       0.0 1
#    Last_name    Fare  FamilySize  Survived
# 92   Chaffee  61.175           2       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 724  Chambers  53.1           2       1.0
# 809  Chambers  53.1           2       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 594   Chapman  26.0           2       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 166  Chibnall  55.0           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 580   Christy  30.0           3       1.0 1
#        Last_name     Fare  FamilySize  Survived
# 73  Chronopoulos  14.4542           2       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 426    Clarke  26.0           2       1.0 1
#     Last_name   Fare  FamilySize  Survived
# 237   Collyer  26.25           3       1.0
# 637   Collyer  26.25           3       0.0
# 801   Collyer  26.25           3       1.0 3
#     Last_name     Fare  FamilySize  Survived
# 835   Compton  83.1583           3       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 348    Coutts  15.9           3       1.0
# 489    Coutts  15.9           3       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 160     Cribb  16.1           2       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 540    Crosby  71.0           3       1.0
# 745    Crosby  71.0           3       0.0 2
#   Last_name     Fare  FamilySize  Survived
# 1   Cumings  71.2833           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 423    Danbom  14.4           3       0.0
# 616    Danbom  14.4           3       0.0 2
#     Last_name  Fare  FamilySize  Survived
# 671  Davidson  52.0           2       0.0 1
#     Last_name   Fare  FamilySize  Survived
# 565    Davies  24.15           3       0.0 1
#     Last_name   Fare  FamilySize  Survived
# 549    Davies  36.75           3       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 347   Davison  16.1           2       1.0 1
#     Last_name    Fare  FamilySize  Survived
# 93       Dean  20.575           4       0.0
# 788      Dean  20.575           4       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 690      Dick  57.0           2       1.0
# 781      Dick  57.0           2       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 445     Dodge  81.8583           3       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 98     Doling  23.0           2       1.0
# 651    Doling  23.0           2       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 544   Douglas  106.425           2       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 416      Drew  32.5           3       1.0 1
#        Last_name  Fare  FamilySize  Survived
# 556  Duff Gordon  39.6           2       1.0 1
#        Last_name     Fare  FamilySize  Survived
# 599  Duff Gordon  56.9292           2       1.0 1
#         Last_name     Fare  FamilySize  Survived
# 866  Duran y More  13.8583           2       1.0 1
#     Last_name    Fare  FamilySize  Survived
# 352     Elias  7.2292           3       0.0
# 532     Elias  7.2292           3       0.0 2
#     Last_name     Fare  FamilySize  Survived
# 496    Eustis  78.2667           2       1.0 1
#      Last_name  Fare  FamilySize  Survived
# 53  Faunthorpe  26.0           2       1.0 1
#     Last_name    Fare  FamilySize  Survived
# 86       Ford  34.375           5       0.0
# 147      Ford  34.375           5       0.0
# 436      Ford  34.375           5       0.0
# 736      Ford  34.375           5       0.0 4
#     Last_name   Fare  FamilySize  Survived
# 27    Fortune  263.0           6       0.0
# 88    Fortune  263.0           6       1.0
# 341   Fortune  263.0           6       1.0
# 438   Fortune  263.0           6       0.0 4
#       Last_name    Fare  FamilySize  Survived
# 334  Frauenthal  133.65           2       1.0
# 660  Frauenthal  133.65           3       1.0 2
#      Last_name  Fare  FamilySize  Survived
# 539  Frolicher  49.5           3       1.0 1
#             Last_name  Fare  FamilySize  Survived
# 587  Frolicher-Stehli  79.2           3       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 3    Futrelle  53.1           2       1.0
# 137  Futrelle  53.1           2       0.0 2
#     Last_name  Fare  FamilySize  Survived
# 405      Gale  21.0           2       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 861     Giles  11.5           2       0.0 1
#       Last_name     Fare  FamilySize  Survived
# 453  Goldenberg  89.1042           2       1.0
# 849  Goldenberg  89.1042           2       1.0 2
#      Last_name    Fare  FamilySize  Survived
# 165  Goldsmith  20.525           3       1.0
# 328  Goldsmith  20.525           3       1.0
# 548  Goldsmith  20.525           3       0.0 3
#     Last_name  Fare  FamilySize  Survived
# 59    Goodwin  46.9           8       0.0
# 71    Goodwin  46.9           8       0.0
# 386   Goodwin  46.9           8       0.0
# 480   Goodwin  46.9           8       0.0
# 678   Goodwin  46.9           8       0.0
# 683   Goodwin  46.9           8       0.0 6
#     Last_name      Fare  FamilySize  Survived
# 268    Graham  153.4625           2       1.0
# 332    Graham  153.4625           2       0.0 2
#      Last_name     Fare  FamilySize  Survived
# 97  Greenfield  63.3583           2       1.0 1
#       Last_name   Fare  FamilySize  Survived
# 104  Gustafsson  7.925           3       0.0
# 392  Gustafsson  7.925           3       0.0 2
#     Last_name     Fare  FamilySize  Survived
# 451   Hagland  19.9667           2       0.0
# 490   Hagland  19.9667           2       0.0 2
#        Last_name   Fare  FamilySize  Survived
# 142  Hakkarainen  15.85           2       1.0
# 403  Hakkarainen  15.85           2       0.0 2
#       Last_name  Fare  FamilySize  Survived
# 247  Hamalainen  14.5           3       1.0
# 755  Hamalainen  14.5           3       1.0 2
#     Last_name    Fare  FamilySize  Survived
# 704    Hansen  7.8542           2       0.0 1
#     Last_name     Fare  FamilySize  Survived
# 860    Hansen  14.1083           3       0.0 1
#     Last_name     Fare  FamilySize  Survived
# 370    Harder  55.4417           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 720    Harper  33.0           2       1.0
# 848    Harper  33.0           2       0.0 2
#     Last_name     Fare  FamilySize  Survived
# 52     Harper  76.7292           2       1.0
# 645    Harper  76.7292           2       1.0 2
#     Last_name    Fare  FamilySize  Survived
# 62     Harris  83.475           2       0.0
# 230    Harris  83.475           2       1.0 2
#     Last_name   Fare  FamilySize  Survived
# 314      Hart  26.25           3       0.0
# 440      Hart  26.25           3       1.0
# 535      Hart  26.25           3       1.0 3
#     Last_name  Fare  FamilySize  Survived
# 820      Hays  93.5           3       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 615    Herman  65.0           4       1.0
# 754    Herman  65.0           4       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 120   Hickman  73.5           3       0.0
# 655   Hickman  73.5           3       0.0
# 665   Hickman  73.5           3       0.0 3
#     Last_name     Fare  FamilySize  Survived
# 329   Hippach  57.9792           2       1.0
# 523   Hippach  57.9792           2       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 479  Hirvonen  12.2875           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 529   Hocking  11.5           4       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 774   Hocking  23.0           5       1.0 1
#     Last_name     Fare  FamilySize  Survived
# 765  Hogeboom  77.9583           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 236      Hold  26.0           2       0.0 1
#      Last_name  Fare  FamilySize  Survived
# 35   Holverson  52.0           2       0.0
# 383  Holverson  52.0           2       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 224      Hoyt  90.0           2       1.0
# 486      Hoyt  90.0           2       1.0 2
#       Last_name   Fare  FamilySize  Survived
# 729  Ilmakangas  7.925           2       0.0 1
#      Last_name  Fare  FamilySize  Survived
# 217  Jacobsohn  27.0           2       0.0
# 600  Jacobsohn  27.0           4       1.0 2
#     Last_name    Fare  FamilySize  Survived
# 721    Jensen  7.0542           2       0.0 1
#     Last_name     Fare  FamilySize  Survived
# 8     Johnson  11.1333           3       1.0
# 172   Johnson  11.1333           3       1.0
# 869   Johnson  11.1333           3       1.0 3
#     Last_name   Fare  FamilySize  Survived
# 783  Johnston  23.45           4       0.0
# 888  Johnston  23.45           4       0.0 2
#     Last_name   Fare  FamilySize  Survived
# 113   Jussila  9.825           2       0.0
# 402   Jussila  9.825           2       0.0 2
#     Last_name  Fare  FamilySize  Survived
# 99     Kantor  26.0           2       0.0
# 316    Kantor  26.0           2       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 691     Karun  13.4167           2       1.0 1
#     Last_name     Fare  FamilySize  Survived
# 457    Kenyon  51.8625           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 214   Kiernan  7.75           2       0.0 1
#     Last_name     Fare  FamilySize  Survived
# 621   Kimball  52.5542           2       1.0 1
#    Last_name    Fare  FamilySize  Survived
# 69      Kink  8.6625           3       0.0 1
#          Last_name    Fare  FamilySize  Survived
# 184  Kink-Heilmann  22.025           3       1.0 1
#     Last_name    Fare  FamilySize  Survived
# 175    Klasen  7.8542           3       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 312  Lahtinen  26.0           3       0.0 1
#     Last_name     Fare  FamilySize  Survived
# 43    Laroche  41.5792           4       1.0
# 608   Laroche  41.5792           4       1.0
# 685   Laroche  41.5792           4       0.0 3
#     Last_name     Fare  FamilySize  Survived
# 176   Lefebre  25.4667           5       0.0
# 229   Lefebre  25.4667           5       0.0
# 409   Lefebre  25.4667           5       0.0
# 485   Lefebre  25.4667           5       0.0 4
#    Last_name  Fare  FamilySize  Survived
# 46    Lennon  15.5           2       0.0 1
#     Last_name   Fare  FamilySize  Survived
# 605   Lindell  15.55           2       0.0 1
#      Last_name   Fare  FamilySize  Survived
# 664  Lindqvist  7.925           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 853     Lines  39.4           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 253      Lobb  16.1           2       0.0
# 617      Lobb  16.1           2       0.0 2
#     Last_name  Fare  FamilySize  Survived
# 432     Louch  26.0           2       1.0 1
#     Last_name      Fare  FamilySize  Survived
# 689    Madill  211.3375           2       1.0 1
#     Last_name     Fare  FamilySize  Survived
# 817    Mallet  37.0042           3       0.0
# 827    Mallet  37.0042           3       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 748    Marvin  53.1           2       0.0 1
#     Last_name   Fare  FamilySize  Survived
# 301     McCoy  23.25           3       1.0
# 330     McCoy  23.25           3       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 743   McNamee  16.1           2       0.0 1
#      Last_name  Fare  FamilySize  Survived
# 272  Mellinger  19.5           2       1.0
# 446  Mellinger  19.5           2       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 34      Meyer  82.1708           2       0.0
# 375     Meyer  82.1708           2       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 245   Minahan  90.0           3       0.0
# 412   Minahan  90.0           2       1.0 2
#     Last_name    Fare  FamilySize  Survived
# 751      Moor  12.475           2       1.0
# 823      Moor  12.475           2       1.0 2
#     Last_name   Fare  FamilySize  Survived
# 109     Moran  24.15           2       1.0
# 768     Moran  24.15           2       0.0 2
#     Last_name     Fare  FamilySize  Survived
# 65   Moubarek  15.2458           3       1.0
# 709  Moubarek  15.2458           3       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 241    Murphy  15.5           2       1.0
# 612    Murphy  15.5           2       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 381     Nakid  15.7417           3       1.0
# 622     Nakid  15.7417           3       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 9      Nasser  30.0708           2       1.0
# 122    Nasser  30.0708           2       0.0 2
#     Last_name  Fare  FamilySize  Survived
# 273    Natsch  29.7           2       0.0 1
#     Last_name  Fare  FamilySize  Survived
# 148  Navratil  26.0           3       0.0
# 193  Navratil  26.0           3       1.0
# 340  Navratil  26.0           3       1.0 3
#     Last_name     Fare  FamilySize  Survived
# 215    Newell  113.275           2       1.0
# 393    Newell  113.275           2       1.0
# 659    Newell  113.275           3       0.0 3
#     Last_name     Fare  FamilySize  Survived
# 136    Newsom  26.2833           3       1.0 1
#     Last_name   Fare  FamilySize  Survived
# 145  Nicholls  36.75           3       0.0 1
#          Last_name     Fare  FamilySize  Survived
# 39   Nicola-Yarred  11.2417           2       1.0
# 125  Nicola-Yarred  11.2417           2       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 186   O'Brien  15.5           2       1.0
# 364   O'Brien  15.5           2       0.0 2
#     Last_name    Fare  FamilySize  Survived
# 197     Olsen  8.4042           2       0.0 1
#    Last_name     Fare  FamilySize  Survived
# 54     Ostby  61.9792           2       0.0 1
#     Last_name    Fare  FamilySize  Survived
# 7     Palsson  21.075           5       0.0
# 24    Palsson  21.075           5       0.0
# 374   Palsson  21.075           5       0.0
# 567   Palsson  21.075           5       0.0 4
#     Last_name     Fare  FamilySize  Survived
# 50     Panula  39.6875           6       0.0
# 164    Panula  39.6875           6       0.0
# 266    Panula  39.6875           6       0.0
# 638    Panula  39.6875           6       0.0
# 686    Panula  39.6875           6       0.0
# 824    Panula  39.6875           6       0.0 6
#     Last_name  Fare  FamilySize  Survived
# 259   Parrish  26.0           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 151     Pears  66.6           2       1.0
# 336     Pears  66.6           2       0.0 2
#                 Last_name   Fare  FamilySize  Survived
# 307  Penasco y Castellana  108.9           2       1.0
# 505  Penasco y Castellana  108.9           2       0.0 2
#     Last_name   Fare  FamilySize  Survived
# 267   Persson  7.775           2       1.0 1
#     Last_name     Fare  FamilySize  Survived
# 128     Peter  22.3583           3       1.0
# 533     Peter  22.3583           3       1.0 2
#      Last_name   Fare  FamilySize  Survived
# 442  Petterson  7.775           2       0.0 1
#     Last_name     Fare  FamilySize  Survived
# 879    Potter  83.1583           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 506     Quick  26.0           3       1.0
# 530     Quick  26.0           3       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 476    Renouf  21.0           2       0.0
# 726    Renouf  21.0           4       1.0 2
#     Last_name    Fare  FamilySize  Survived
# 16       Rice  29.125           6       0.0
# 171      Rice  29.125           6       0.0
# 278      Rice  29.125           6       0.0
# 787      Rice  29.125           6       0.0
# 885      Rice  29.125           6       0.0 5
#     Last_name   Fare  FamilySize  Survived
# 407  Richards  18.75           3       1.0
# 437  Richards  18.75           6       1.0
# 831  Richards  18.75           3       1.0 3
#     Last_name      Fare  FamilySize  Survived
# 779    Robert  211.3375           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 132    Robins  14.5           2       0.0 1
#     Last_name     Fare  FamilySize  Survived
# 254   Rosblom  20.2125           3       0.0
# 424   Rosblom  20.2125           3       0.0 2
#       Last_name  Fare  FamilySize  Survived
# 513  Rothschild  59.4           2       1.0 1
#     Last_name     Fare  FamilySize  Survived
# 311   Ryerson  262.375           5       1.0
# 742   Ryerson  262.375           5       1.0 2
#     Last_name   Fare  FamilySize  Survived
# 159      Sage  69.55          11       0.0
# 180      Sage  69.55          11       0.0
# 201      Sage  69.55          11       0.0
# 324      Sage  69.55          11       0.0
# 792      Sage  69.55          11       0.0
# 846      Sage  69.55          11       0.0
# 863      Sage  69.55          11       0.0 7
#    Last_name     Fare  FamilySize  Survived
# 48    Samaan  21.6792           3       0.0 1
#      Last_name  Fare  FamilySize  Survived
# 10   Sandstrom  16.7           3       1.0
# 394  Sandstrom  16.7           3       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 880   Shelley  26.0           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 417    Silven  13.0           3       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 434    Silvey  55.9           2       0.0
# 577    Silvey  55.9           2       1.0 2
#     Last_name  Fare  FamilySize  Survived
# 63      Skoog  27.9           6       0.0
# 167     Skoog  27.9           6       0.0
# 360     Skoog  27.9           6       0.0
# 634     Skoog  27.9           6       0.0
# 642     Skoog  27.9           6       0.0
# 819     Skoog  27.9           6       0.0 6
#     Last_name   Fare  FamilySize  Survived
# 319   Spedden  134.5           3       1.0 1
#    Last_name      Fare  FamilySize  Survived
# 31   Spencer  146.5208           2       1.0 1
#       Last_name     Fare  FamilySize  Survived
# 591  Stephenson  78.2667           2       1.0 1
#     Last_name     Fare  FamilySize  Survived
# 205     Strom  10.4625           2       0.0
# 251     Strom  10.4625           3       0.0 2
#     Last_name   Fare  FamilySize  Survived
# 262   Taussig  79.65           3       0.0
# 558   Taussig  79.65           3       1.0
# 585   Taussig  79.65           3       1.0 3
#     Last_name  Fare  FamilySize  Survived
# 669    Taylor  52.0           2       1.0
# 712    Taylor  52.0           2       1.0 2
#     Last_name      Fare  FamilySize  Survived
# 550    Thayer  110.8833           3       1.0
# 581    Thayer  110.8833           3       1.0
# 698    Thayer  110.8833           3       0.0 3
#     Last_name    Fare  FamilySize  Survived
# 803    Thomas  8.5167           2       1.0 1
#         Last_name  Fare  FamilySize  Survived
# 431  Thorneycroft  16.1           2       1.0
# 639  Thorneycroft  16.1           2       0.0 2
#     Last_name     Fare  FamilySize  Survived
# 255     Touma  15.2458           3       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 41     Turpin  21.0           2       0.0
# 117    Turpin  21.0           2       0.0 2
#     Last_name   Fare  FamilySize  Survived
# 419  Van Impe  24.15           3       0.0
# 595  Van Impe  24.15           3       0.0
# 799  Van Impe  24.15           3       0.0 3
#          Last_name  Fare  FamilySize  Survived
# 18   Vander Planke  18.0           2       0.0
# 38   Vander Planke  18.0           3       0.0
# 333  Vander Planke  18.0           3       0.0 3
#     Last_name   Fare  FamilySize  Survived
# 366    Warren  75.25           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 133     Weisz  26.0           2       1.0 1
#     Last_name  Fare  FamilySize  Survived
# 750     Wells  23.0           3       1.0 1
#     Last_name   Fare  FamilySize  Survived
# 58       West  27.75           4       1.0
# 450      West  27.75           4       0.0
# 472      West  27.75           4       1.0 3
#     Last_name     Fare  FamilySize  Survived
# 102     White  77.2875           2       0.0
# 124     White  77.2875           2       0.0 2
#     Last_name      Fare  FamilySize  Survived
# 318      Wick  164.8667           3       1.0
# 856      Wick  164.8667           3       1.0 2
#     Last_name   Fare  FamilySize  Survived
# 377   Widener  211.5           3       0.0 1
#     Last_name    Fare  FamilySize  Survived
# 371   Wiklund  6.4958           2       0.0 1
#     Last_name     Fare  FamilySize  Survived
# 155  Williams  61.3792           2       0.0 1
#     Last_name     Fare  FamilySize  Survived
# 620   Yasbeck  14.4542           2       0.0
# 830   Yasbeck  14.4542           2       1.0 2
#     Last_name     Fare  FamilySize  Survived
# 111    Zabour  14.4542           2       0.0
# 240    Zabour  14.4542           2       0.0 2
#           Last_name  Fare  FamilySize  Survived
# 559  de Messemaeker  17.4           2       1.0 1
#      Last_name     Fare  FamilySize  Survived
# 361  del Carlo  27.7208           2       0.0 1
#         Last_name  Fare  FamilySize  Survived
# 153  van Billiard  14.5           3       0.0 1

# %%
family_df = pd.DataFrame(data=family_df_grpby.size(), columns=['Size in train'])
family_df['Survived total'] = family_df_grpby['Survived'].sum().astype(int)
family_df['FamilySize'] = family_df_grpby['FamilySize'].mean().astype(int)

# %%
family_df.head()
# Out:
#                    Size in train  Survived total  FamilySize
# Last_name Fare
# Abbott    20.250               2               1           3
# Abelson   24.000               2               1           2
# Ahlin     9.475                1               0           2
# Aks       9.350                1               1           2
# Allison   151.550              3               1           4

# %%
#family_df = family_df[family_df['FamilySize']==8]
print("Whole family survived: %.1f" 
      %(100*len(family_df[family_df['Size in train']==family_df['Survived total'] ])/len(family_df))+'%') 
print("Whole family perished: %.1f" 
      %(100*len(family_df[family_df['Survived total'] == 0])/len(family_df))+'%')
# Out:
# Whole family survived: 44.7%
# Whole family perished: 35.7%

# %%
data['Fare'].fillna(data['Fare'].mean(),inplace = True)

DEFAULT_SURVIVAL_VALUE = 0.5
data['Family_Survival'] = DEFAULT_SURVIVAL_VALUE

for grp, grp_df in data[['Survived','Name', 'Last_name', 'Fare', 'Ticket', 'PassengerId',
                           'SibSp', 'Parch', 'Age', 'Cabin']].groupby(['Last_name', 'Fare']):
    
    print(grp_df)
    if(len(grp_df) != 1):
        #A Family group is found
        for ind,row in grp_df.iterrows():
            smax = grp_df.drop(ind)['Survived'].max()
            smin = grp_df.drop(ind)['Survived'].min()
            passID = row['PassengerId']
            if (smax == 1.0):
                data.loc[data['PassengerId'] == passID, 'Family_Survival'] = 1
            elif (smin == 0.0):
                data.loc[data['PassengerId'] == passID, 'Family_Survival'] = 0 
                
print("Number of passengers with family survival information:",
     data.loc[data["Family_Survival"] !=0.5].shape[0])
# Out:
#      Survived                 Name Last_name  Fare     Ticket  PassengerId  \
# 845       0.0  Abbing, Mr. Anthony    Abbing  7.55  C.A. 5547          846
#
#      SibSp  Parch   Age Cabin
# 845      0      0  42.0   NaN
#      Survived                              Name Last_name   Fare     Ticket  \
# 279       1.0  Abbott, Mrs. Stanton (Rosa Hunt)    Abbott  20.25  C.A. 2673
# 746       0.0       Abbott, Mr. Rossmore Edward    Abbott  20.25  C.A. 2673
# 392       NaN     Abbott, Master. Eugene Joseph    Abbott  20.25  C.A. 2673
#
#      PassengerId  SibSp  Parch   Age Cabin
# 279          280      1      1  35.0   NaN
# 746          747      1      1  16.0   NaN
# 392         1284      0      2  13.0   NaN
#      Survived                           Name Last_name  Fare  Ticket  \
# 57        NaN  Abelseth, Mr. Olaus Jorgensen  Abelseth  7.65  348122
# 345       NaN    Abelseth, Miss. Karen Marie  Abelseth  7.65  348125
#
#      PassengerId  SibSp  Parch   Age  Cabin
# 57           949      0      0  25.0  F G63
# 345         1237      0      0  16.0    NaN
#      Survived                                   Name Last_name  Fare  \
# 308       0.0                    Abelson, Mr. Samuel   Abelson  24.0
# 874       1.0  Abelson, Mrs. Samuel (Hannah Wizosky)   Abelson  24.0
#
#         Ticket  PassengerId  SibSp  Parch   Age Cabin
# 308  P/PP 3381          309      1      0  30.0   NaN
# 874  P/PP 3381          875      1      0  28.0   NaN
#      Survived                                      Name    Last_name   Fare  \
# 251       NaN  Abrahamsson, Mr. Abraham August Johannes  Abrahamsson  7.925
#
#                Ticket  PassengerId  SibSp  Parch   Age Cabin
# 251  SOTON/O2 3101284         1143      0      0  20.0   NaN
#    Survived                                       Name Last_name    Fare  \
# 8       NaN  Abrahim, Mrs. Joseph (Sophie Halaut Easu)   Abrahim  7.2292
#
#   Ticket  PassengerId  SibSp  Parch   Age Cabin
# 8   2657          900      0      0  18.0   NaN
#      Survived                            Name Last_name  Fare  Ticket  \
# 365       0.0  Adahl, Mr. Mauritz Nils Martin     Adahl  7.25  C 7076
#
#      PassengerId  SibSp  Parch   Age Cabin
# 365          366      0      0  30.0   NaN
#      Survived             Name Last_name  Fare  Ticket  PassengerId  SibSp  \
# 401       0.0  Adams, Mr. John     Adams  8.05  341826          402      0
#
#      Parch   Age Cabin
# 401      0  26.0   NaN
#     Survived                                            Name Last_name   Fare  \
# 40       0.0  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)     Ahlin  9.475
#
#    Ticket  PassengerId  SibSp  Parch   Age Cabin
# 40   7546           41      1      0  40.0   NaN
#      Survived                        Name Last_name  Fare  Ticket  \
# 855       1.0  Aks, Mrs. Sam (Leah Rosen)       Aks  9.35  392091
# 307       NaN   Aks, Master. Philip Frank       Aks  9.35  392091
#
#      PassengerId  SibSp  Parch    Age Cabin
# 855          856      0      1  18.00   NaN
# 307         1199      0      1   0.83   NaN
#      Survived                         Name Last_name     Fare Ticket  \
# 207       1.0  Albimona, Mr. Nassef Cassem  Albimona  18.7875   2699
#
#      PassengerId  SibSp  Parch   Age Cabin
# 207          208      0      0  26.0   NaN
#     Survived                            Name Last_name  Fare  Ticket  \
# 78       NaN  Aldworth, Mr. Charles Augustus  Aldworth  13.0  248744
#
#     PassengerId  SibSp  Parch   Age Cabin
# 78          970      0      0  30.0   NaN
#      Survived                    Name  Last_name    Fare Ticket  PassengerId  \
# 810       0.0  Alexander, Mr. William  Alexander  7.8875   3474          811
#
#      SibSp  Parch   Age Cabin
# 810      0      0  26.0   NaN
#      Survived                         Name Last_name   Fare            Ticket  \
# 840       0.0  Alhomaki, Mr. Ilmari Rudolf  Alhomaki  7.925  SOTON/O2 3101287
#
#      PassengerId  SibSp  Parch   Age Cabin
# 840          841      0      0  20.0   NaN
#      Survived              Name Last_name  Fare              Ticket  \
# 210       0.0    Ali, Mr. Ahmed       Ali  7.05  SOTON/O.Q. 3101311
# 784       0.0  Ali, Mr. William       Ali  7.05  SOTON/O.Q. 3101312
#
#      PassengerId  SibSp  Parch   Age Cabin
# 210          211      0      0  24.0   NaN
# 784          785      0      0  25.0   NaN
#    Survived                      Name Last_name  Fare  Ticket  PassengerId  \
# 4       0.0  Allen, Mr. William Henry     Allen  8.05  373450            5
#
#    SibSp  Parch   Age Cabin
# 4      0      0  35.0   NaN
#      Survived                           Name Last_name      Fare Ticket  \
# 730       1.0  Allen, Miss. Elisabeth Walton     Allen  211.3375  24160
#
#      PassengerId  SibSp  Parch   Age Cabin
# 730          731      0      0  29.0    B5
#      Survived                                             Name Last_name  \
# 297       0.0                     Allison, Miss. Helen Loraine   Allison
# 305       1.0                   Allison, Master. Hudson Trevor   Allison
# 498       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   Allison
# 306       NaN             Allison, Mr. Hudson Joshua Creighton   Allison
#
#        Fare  Ticket  PassengerId  SibSp  Parch    Age    Cabin
# 297  151.55  113781          298      1      2   2.00  C22 C26
# 305  151.55  113781          306      1      2   0.92  C22 C26
# 498  151.55  113781          499      1      2  25.00  C22 C26
# 306  151.55  113781         1198      1      2  30.00  C22 C26
#      Survived                    Name Last_name  Fare Ticket  PassengerId  \
# 834       0.0  Allum, Mr. Owen George     Allum   8.3   2223          835
#
#      SibSp  Parch   Age Cabin
# 834      0      0  18.0   NaN
#      Survived                         Name Last_name    Fare  Ticket  \
# 210       NaN  Andersen, Mr. Albert Karvin  Andersen  22.525  C 4001
#
#      PassengerId  SibSp  Parch   Age Cabin
# 210         1102      0      0  32.0   NaN
#      Survived                                             Name  \
# 192       1.0  Andersen-Jensen, Miss. Carla Christine Nielsine
#
#            Last_name    Fare  Ticket  PassengerId  SibSp  Parch   Age Cabin
# 192  Andersen-Jensen  7.8542  350046          193      1      0  19.0   NaN
#      Survived                 Name Last_name   Fare Ticket  PassengerId  \
# 460       1.0  Anderson, Mr. Harry  Anderson  26.55  19952          461
#
#      SibSp  Parch   Age Cabin
# 460      0      0  48.0   E12
#      Survived                                    Name  Last_name   Fare  \
# 214       NaN  Andersson, Miss. Ida Augusta Margareta  Andersson  7.775
# 320       NaN             Andersson, Mr. Johan Samuel  Andersson  7.775
#
#      Ticket  PassengerId  SibSp  Parch   Age Cabin
# 214  347091         1106      4      2  38.0   NaN
# 320  347075         1212      0      0  26.0   NaN
#      Survived                                          Name  Last_name  \
# 146       1.0  Andersson, Mr. August Edvard ("Wennerstrom")  Andersson
#
#        Fare  Ticket  PassengerId  SibSp  Parch   Age Cabin
# 146  7.7958  350043          147      0      0  27.0   NaN
#     Survived                             Name  Last_name   Fare   Ticket  \
# 68       1.0  Andersson, Miss. Erna Alexandra  Andersson  7.925  3101281
#
#     PassengerId  SibSp  Parch   Age Cabin
# 68           69      4      2  17.0   NaN
#      Survived                                               Name  Last_name  \
# 13        0.0                        Andersson, Mr. Anders Johan  Andersson
# 119       0.0                  Andersson, Miss. Ellis Anna Maria  Andersson
# 541       0.0               Andersson, Miss. Ingeborg Constanzia  Andersson
# 542       0.0                  Andersson, Miss. Sigrid Elisabeth  Andersson
# 610       0.0  Andersson, Mrs. Anders Johan (Alfrida Konstant...  Andersson
# 813       0.0                 Andersson, Miss. Ebba Iris Alfrida  Andersson
# 850       0.0            Andersson, Master. Sigvard Harald Elias  Andersson
#
#        Fare  Ticket  PassengerId  SibSp  Parch   Age Cabin
# 13   31.275  347082           14      1      5  39.0   NaN
# 119  31.275  347082          120      4      2   2.0   NaN
# 541  31.275  347082          542      4      2   9.0   NaN
# 542  31.275  347082          543      4      2  11.0   NaN
# 610  31.275  347082          611      1      5  39.0   NaN
# 813  31.275  347082          814      4      2   6.0   NaN
# 850  31.275  347082          851      4      2   4.0   NaN
#     Survived                        Name   Last_name    Fare  Ticket  \
# 91       0.0  Andreasson, Mr. Paul Edvin  Andreasson  7.8542  347466
#
#     PassengerId  SibSp  Parch   Age Cabin
# 91           92      0      0  20.0   NaN
#      Survived                      Name Last_name  Fare      Ticket  \
# 204       NaN  Andrew, Mr. Frank Thomas    Andrew  10.5  C.A. 34050
#
#      PassengerId  SibSp  Parch   Age Cabin
# 204         1096      0      0  25.0   NaN
#      Survived                        Name Last_name  Fare  Ticket  \
# 144       0.0  Andrew, Mr. Edgardo Samuel    Andrew  11.5  231945
#
#      PassengerId  SibSp  Parch   Age Cabin
# 144          145      0      0  18.0   NaN
#      Survived                    Name Last_name  Fare  Ticket  PassengerId  \
# 806       0.0  Andrews, Mr. Thomas Jr   Andrews   0.0  112050          807
#
#      SibSp  Parch   Age Cabin
# 806      0      0  39.0   A36
#      Survived                               Name Last_name     Fare Ticket  \
# 275       1.0  Andrews, Miss. Kornelia Theodosia   Andrews  77.9583  13502
#
#      PassengerId  SibSp  Parch   Age Cabin
# 275          276      1      0  63.0    D7
#      Survived                  Name  Last_name    Fare  Ticket  PassengerId  \
# 295       NaN  Angheloff, Mr. Minko  Angheloff  7.8958  349202         1187
#
#      SibSp  Parch   Age Cabin
# 295      0      0  26.0   NaN
#      Survived                                               Name Last_name  \
# 518       1.0  Angle, Mrs. William A (Florence "Mary" Agnes H...     Angle
# 190       NaN                               Angle, Mr. William A     Angle
#
#      Fare  Ticket  PassengerId  SibSp  Parch   Age Cabin
# 518  26.0  226875          519      1      0  36.0   NaN
# 190  26.0  226875         1082      1      0  34.0   NaN
#      Survived                                           Name Last_name  \
# 571       1.0  Appleton, Mrs. Edward Dale (Charlotte Lamson)  Appleton
#
#         Fare Ticket  PassengerId  SibSp  Parch   Age Cabin
# 571  51.4792  11769          572      2      0  53.0  C101
#      Survived                                           Name       Last_name  \
# 49        0.0  Arnold-Franchi, Mrs. Josef (Josefine Franchi)  Arnold-Franchi
# 353       0.0                      Arnold-Franchi, Mr. Josef  Arnold-Franchi
#
#      Fare  Ticket  PassengerId  SibSp  Parch   Age Cabin
# 49   17.8  349237           50      1      0  18.0   NaN
# 353  17.8  349237          354      1      0  25.0   NaN
#      Survived                            Name Last_name   Fare  Ticket  \
# 386       NaN  Aronsson, Mr. Ernst Axel Algot  Aronsson  7.775  349911
#
#      PassengerId  SibSp  Parch   Age Cabin
# 386         1278      0      0  24.0   NaN
#      Survived                     Name     Last_name     Fare    Ticket  \
# 493       0.0  Artagaveytia, Mr. Ramon  Artagaveytia  49.5042  PC 17609
#
#      PassengerId  SibSp  Parch   Age Cabin
# 493          494      0      0  71.0   NaN
#      Survived             Name Last_name  Fare  Ticket  PassengerId  SibSp  \
# 387       NaN  Ashby, Mr. John     Ashby  13.0  244346         1279      0
#
#      Parch   Age Cabin
# 387      0  57.0   NaN
#      Survived             Name Last_name  Fare              Ticket  \
# 363       0.0  Asim, Mr. Adola      Asim  7.05  SOTON/O.Q. 3101310
#
#      PassengerId  SibSp  Parch   Age Cabin
# 363          364      0      0  35.0   NaN
#      Survived                        Name Last_name    Fare  Ticket  \
# 226       NaN  Asplund, Mr. Johan Charles   Asplund  7.7958  350054
#
#      PassengerId  SibSp  Parch   Age Cabin
# 226         1118      0      0  23.0   NaN
#      Survived                                               Name Last_name  \
# 25        1.0  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...   Asplund
# 182       0.0              Asplund, Master. Clarence Gustaf Hugo   Asplund
# 233       1.0                     Asplund, Miss. Lillian Gertrud   Asplund
# 261       1.0                  Asplund, Master. Edvin Rojj Felix   Asplund
# 154       NaN                       Asplund, Master. Filip Oscar   Asplund
# 174       NaN         Asplund, Mr. Carl Oscar Vilhelm Gustafsson   Asplund
# 379       NaN                        Asplund, Master. Carl Edgar   Asplund
#
#         Fare  Ticket  PassengerId  SibSp  Parch   Age Cabin
# 25   31.3875  347077           26      1      5  38.0   NaN
# 182  31.3875  347077          183      4      2   9.0   NaN
# 233  31.3875  347077          234      4      2   5.0   NaN
# 261  31.3875  347077          262      4      2   3.0   NaN
# 154  31.3875  347077         1046      4      2  13.0   NaN
# 174  31.3875  347077         1066      1      5  40.0   NaN
# 379  31.3875  347077         1271      4      2   5.0   NaN
#     Survived               Name Last_name   Fare Ticket  PassengerId  SibSp  \
# 17       NaN  Assaf, Mr. Gerios     Assaf  7.225   2692          909      0
#
#     Parch   Age Cabin
# 17      0  21.0   NaN
#     Survived                                   Name     Last_name   Fare  \
# 19       NaN  Assaf Khalil, Mrs. Mariana (Miriam")"  Assaf Khalil  7.225
#
#    Ticket  PassengerId  SibSp  Parch   Age Cabin
# 19   2696          911      0      0  45.0   NaN
#      Survived            Name Last_name  Fare              Ticket  \
# 325       NaN  Assam, Mr. Ali     Assam  7.05  SOTON/O.Q. 3101309
#
#      PassengerId  SibSp  Parch   Age Cabin
# 325         1217      0      0  23.0   NaN
#      Survived                                               Name Last_name  \
# 700       1.0  Astor, Mrs. John Jacob (Madeleine Talmadge Force)     Astor
# 202       NaN                             Astor, Col. John Jacob     Astor
#
#         Fare    Ticket  PassengerId  SibSp  Parch   Age    Cabin
# 700  227.525  PC 17757          701      1      0  18.0  C62 C64
# 202  227.525  PC 17757         1094      1      0  47.0  C62 C64
#      Survived                  Name Last_name   Fare Ticket  PassengerId  \
# 244       0.0  Attalah, Mr. Sleiman   Attalah  7.225   2694          245
#
#      SibSp  Parch   Age Cabin
# 244      0      0  30.0   NaN
#      Survived                   Name Last_name     Fare Ticket  PassengerId  \
# 114       0.0  Attalah, Miss. Malake   Attalah  14.4583   2627          115
#
#      SibSp  Parch   Age Cabin
# 114      0      0  17.0   NaN
#      Survived                           Name Last_name  Fare    Ticket  \
# 369       1.0  Aubart, Mme. Leontine Pauline    Aubart  69.3  PC 17477
#
#      PassengerId  SibSp  Parch   Age Cabin
# 369          370      0      0  24.0   B35
#      Survived                    Name   Last_name    Fare  Ticket  \
# 833       0.0  Augustsson, Mr. Albert  Augustsson  7.8542  347468
#
#      PassengerId  SibSp  Parch   Age Cabin
# 833          834      0      0  23.0   NaN
#      Survived                  Name Last_name    Fare Ticket  PassengerId  \
# 780       1.0  Ayoub, Miss. Banoura     Ayoub  7.2292   2687          781
#
#      SibSp  Parch   Age Cabin
# 780      0      0  13.0   NaN
#      Survived                 Name Last_name   Fare Ticket  PassengerId  \
# 237       NaN  Baccos, Mr. Raffull    Baccos  7.225   2679         1129
#
#      SibSp  Parch   Age Cabin
# 237      0      0  20.0   NaN
#      Survived                                               Name  Last_name  \
# 85        1.0  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  Backstrom
# 206       0.0                         Backstrom, Mr. Karl Alfred  Backstrom
#
#       Fare   Ticket  PassengerId  SibSp  Parch   Age Cabin
# 85   15.85  3101278           86      3      0  33.0   NaN
# 206  15.85  3101278          207      1      0  32.0   NaN
#      Survived                                   Name Last_name     Fare  \
# 448       1.0         Baclini, Miss. Marie Catherine   Baclini  19.2583
# 469       1.0          Baclini, Miss. Helene Barbara   Baclini  19.2583
# 644       1.0                 Baclini, Miss. Eugenie   Baclini  19.2583
# 858       1.0  Baclini, Mrs. Solomon (Latifa Qurban)   Baclini  19.2583
#
#     Ticket  PassengerId  SibSp  Parch    Age Cabin
# 448   2666          449      2      1   5.00   NaN
# 469   2666          470      2      1   0.75   NaN
# 644   2666          645      2      1   0.75   NaN
# 858   2666          859      0      3  24.00   NaN
#     Survived                        Name Last_name  Fare     Ticket  \
# 87       NaN  Badman, Miss. Emily Louisa    Badman  8.05  A/4 31416
#
#     PassengerId  SibSp  Parch   Age Cabin
# 87          979      0      0  18.0   NaN
#      Survived               Name Last_name   Fare Ticket  PassengerId  SibSp  \
# 661       0.0  Badt, Mr. Mohamed      Badt  7.225   2623          662      0
#
#      Parch   Age Cabin
# 661      0  40.0   NaN
#      Survived                      Name Last_name  Fare Ticket  PassengerId  \
# 757       0.0  Bailey, Mr. Percy Andrew    Bailey  11.5  29108          758
#
#      SibSp  Parch   Age Cabin
# 757      0      0  18.0   NaN
#      Survived                            Name   Last_name  Fare      Ticket  \
# 198       NaN  Baimbrigge, Mr. Charles Robert  Baimbrigge  10.5  C.A. 31030
#
#      PassengerId  SibSp  Parch   Age Cabin
# 198         1090      0      0  23.0   NaN
#      Survived               Name Last_name    Fare  Ticket  PassengerId  \
# 870       0.0  Balkic, Mr. Cerin    Balkic  7.8958  349248          871
#
#      SibSp  Parch   Age Cabin
# 870      0      0  26.0   NaN
#      Survived                     Name Last_name  Fare Ticket  PassengerId  \
# 327       1.0  Ball, Mrs. (Ada E Hall)      Ball  13.0  28551          328
#
#      SibSp  Parch   Age Cabin
# 327      0      0  36.0     D
#      Survived                           Name Last_name  Fare  \
# 883       0.0  Banfield, Mr. Frederick James  Banfield  10.5
#
#                Ticket  PassengerId  SibSp  Parch   Age Cabin
# 883  C.A./SOTON 34068          884      0      0  28.0   NaN
#      Survived                   Name Last_name    Fare Ticket  PassengerId  \
# 762       1.0  Barah, Mr. Hanna Assi     Barah  7.2292   2663          763
#
#      SibSp  Parch   Age Cabin
# 762      0      0  20.0   NaN
#      Survived                             Name Last_name     Fare Ticket  \
# 362       0.0  Barbara, Mrs. (Catherine David)   Barbara  14.4542   2691
# 702       0.0            Barbara, Miss. Saiide   Barbara  14.4542   2691
#
#      PassengerId  SibSp  Parch   Age Cabin
# 362          363      0      1  45.0   NaN
# 702          703      0      1  18.0   NaN
#      Survived                          Name Last_name   Fare Ticket  \
# 290       1.0  Barber, Miss. Ellen "Nellie"    Barber  78.85  19877
#
#      PassengerId  SibSp  Parch   Age Cabin
# 290          291      0      0  26.0   NaN
#      Survived                                  Name  Last_name  Fare Ticket  \
# 630       1.0  Barkworth, Mr. Algernon Henry Wilson  Barkworth  30.0  27042
#
#      PassengerId  SibSp  Parch   Age Cabin
# 630          631      0      0  80.0   A23
#     Survived                Name Last_name    Fare  Ticket  PassengerId  \
# 86       NaN  Barry, Miss. Julia     Barry  7.8792  330844          978
#
#     SibSp  Parch   Age Cabin
# 86      0      0  27.0   NaN
#      Survived                    Name Last_name  Fare  Ticket  PassengerId  \
# 112       0.0  Barton, Mr. David John    Barton  8.05  324669          113
#
#      SibSp  Parch   Age Cabin
# 112      0      0  22.0   NaN
#      Survived                        Name Last_name    Fare       Ticket  \
# 150       0.0  Bateman, Rev. Robert James   Bateman  12.525  S.O.P. 1166
#
#      PassengerId  SibSp  Parch   Age Cabin
# 150          151      0      0  51.0   NaN
#      Survived                 Name Last_name    Fare    Ticket  PassengerId  \
# 168       0.0  Baumann, Mr. John D   Baumann  25.925  PC 17318          169
#
#      SibSp  Parch   Age Cabin
# 168      0      0  42.0   NaN
#      Survived                                             Name Last_name  \
# 118       0.0                         Baxter, Mr. Quigg Edmond    Baxter
# 299       1.0  Baxter, Mrs. James (Helene DeLaudeniere Chaput)    Baxter
#
#          Fare    Ticket  PassengerId  SibSp  Parch   Age    Cabin
# 118  247.5208  PC 17558          119      0      1  24.0  B58 B60
# 299  247.5208  PC 17558          300      0      1  50.0  B58 B60
#      Survived                   Name Last_name     Fare Ticket  PassengerId  \
# 218       1.0  Bazzani, Miss. Albina   Bazzani  76.2917  11813          219
#
#      SibSp  Parch   Age Cabin
# 218      0      0  32.0   D15
#      Survived                               Name Last_name  Fare Ticket  \
# 543       1.0                  Beane, Mr. Edward     Beane  26.0   2908
# 546       1.0  Beane, Mrs. Edward (Ethel Clarke)     Beane  26.0   2908
#
#      PassengerId  SibSp  Parch   Age Cabin
# 543          544      1      0  32.0   NaN
# 546          547      1      0  19.0   NaN
#      Survived                  Name Last_name     Fare Ticket  PassengerId  \
# 118       NaN  Beattie, Mr. Thomson   Beattie  75.2417  13050         1010
#
#      SibSp  Parch   Age Cabin
# 118      0      0  36.0    C6
#      Survived                        Name  Last_name  Fare  Ticket  \
# 143       NaN  Beauchamp, Mr. Henry James  Beauchamp  26.0  244358
#
#      PassengerId  SibSp  Parch   Age Cabin
# 143         1035      0      0  28.0   NaN
#      Survived                        Name Last_name  Fare  Ticket  \
# 372       0.0  Beavan, Mr. William Thomas    Beavan  8.05  323951
#
#      PassengerId  SibSp  Parch   Age Cabin
# 372          373      0      0  19.0   NaN
#      Survived                                              Name Last_name  \
# 183       1.0                         Becker, Master. Richard F    Becker
# 618       1.0                       Becker, Miss. Marion Louise    Becker
# 178       NaN  Becker, Mrs. Allen Oliver (Nellie E Baumgardner)    Becker
# 326       NaN                      Becker, Miss. Ruth Elizabeth    Becker
#
#      Fare  Ticket  PassengerId  SibSp  Parch   Age Cabin
# 183  39.0  230136          184      2      1   1.0    F4
# 618  39.0  230136          619      2      1   4.0    F4
# 178  39.0  230136         1070      0      3  36.0    F4
# 326  39.0  230136         1218      2      1  12.0    F4
#      Survived                                              Name Last_name  \
# 248       1.0                     Beckwith, Mr. Richard Leonard  Beckwith
# 871       1.0  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  Beckwith
#
#         Fare Ticket  PassengerId  SibSp  Parch   Age Cabin
# 248  52.5542  11751          249      1      1  37.0   D35
# 871  52.5542  11751          872      1      1  47.0   D35
#     Survived                   Name Last_name  Fare  Ticket  PassengerId  \
# 21       1.0  Beesley, Mr. Lawrence   Beesley  13.0  248698           22
#
#     SibSp  Parch   Age Cabin
# 21      0      0  34.0   D56
#      Survived                   Name Last_name  Fare  Ticket  PassengerId  \
# 889       1.0  Behr, Mr. Karl Howell      Behr  30.0  111369          890
#
#      SibSp  Parch   Age Cabin
# 889      0      0  26.0  C148
#      Survived                        Name  Last_name   Fare  Ticket  \
# 162       0.0  Bengtsson, Mr. John Viktor  Bengtsson  7.775  347068
#
#      PassengerId  SibSp  Parch   Age Cabin
# 162          163      0      0  26.0   NaN
#      Survived                     Name Last_name  Fare Ticket  PassengerId  \
# 258       NaN  Bentham, Miss. Lilian W   Bentham  13.0  28404         1150
#
#      SibSp  Parch   Age Cabin
# 258      0      0  19.0   NaN
#      Survived                          Name Last_name  Fare   Ticket  \
# 225       0.0  Berglund, Mr. Karl Ivar Sven  Berglund  9.35  PP 4348
#
#      PassengerId  SibSp  Parch   Age Cabin
# 225          226      0      0  22.0   NaN
#      Survived                        Name Last_name  Fare Ticket  PassengerId  \
# 733       0.0  Berriman, Mr. William John  Berriman  13.0  28425          734
#
#      SibSp  Parch   Age Cabin
# 733      0      0  23.0   NaN
#      Survived                 Name Last_name    Fare Ticket  PassengerId  \
# 378       0.0  Betros, Mr. Tannous    Betros  4.0125   2648          379
#
#      SibSp  Parch   Age Cabin
# 378      0      0  20.0   NaN
#      Survived                   Name Last_name    Fare Ticket  PassengerId  \
# 339       NaN  Betros, Master. Seman    Betros  7.2292   2622         1231
#
#      SibSp  Parch  Age Cabin
# 339      0      0  6.0   NaN
#      Survived                   Name Last_name     Fare    Ticket  \
# 380       1.0  Bidois, Miss. Rosalie    Bidois  227.525  PC 17757
#
#      PassengerId  SibSp  Parch   Age Cabin
# 380          381      0      0  42.0   NaN
#     Survived           Name Last_name     Fare Ticket  PassengerId  SibSp  \
# 74       1.0  Bing, Mr. Lee      Bing  56.4958   1601           75      0
#
#     Parch   Age Cabin
# 74      0  32.0   NaN
#      Survived               Name Last_name      Fare    Ticket  PassengerId  \
# 156       NaN  Bird, Miss. Ellen      Bird  221.7792  PC 17483         1048
#
#      SibSp  Parch   Age Cabin
# 156      0      0  29.0   C97
#      Survived                               Name  Last_name   Fare  Ticket  \
# 408       0.0  Birkeland, Mr. Hans Martin Monsen  Birkeland  7.775  312992
#
#      PassengerId  SibSp  Parch   Age Cabin
# 408          409      0      0  21.0   NaN
#     Survived                 Name Last_name  Fare Ticket  PassengerId  SibSp  \
# 94       NaN  Birnbaum, Mr. Jakob  Birnbaum  26.0  13905          986      0
#
#     Parch   Age Cabin
# 94      0  25.0   NaN
#      Survived                                     Name Last_name     Fare  \
# 291       1.0  Bishop, Mrs. Dickinson H (Helen Walton)    Bishop  91.0792
# 484       1.0                  Bishop, Mr. Dickinson H    Bishop  91.0792
#
#     Ticket  PassengerId  SibSp  Parch   Age Cabin
# 291  11967          292      1      0  19.0   B49
# 484  11967          485      1      0  25.0   B49
#      Survived                    Name Last_name      Fare    Ticket  \
# 269       1.0  Bissette, Miss. Amelia  Bissette  135.6333  PC 17760
#
#      PassengerId  SibSp  Parch   Age Cabin
# 269          270      0      0  35.0   C99
#     Survived                          Name  Last_name  Fare  Ticket  \
# 62       NaN  Bjorklund, Mr. Ernst Herbert  Bjorklund  7.75  347090
#
#     PassengerId  SibSp  Parch   Age Cabin
# 62          954      0      0  18.0   NaN
#      Survived                                       Name  \
# 430       1.0  Bjornstrom-Steffansson, Mr. Mauritz Hakan
#
#                   Last_name   Fare  Ticket  PassengerId  SibSp  Parch   Age  \
# 430  Bjornstrom-Steffansson  26.55  110564          431      0      0  28.0
#
#     Cabin
# 430   C52
#      Survived                          Name  Last_name  Fare  Ticket  \
# 339       0.0  Blackwell, Mr. Stephen Weart  Blackwell  35.5  113784
#
#      PassengerId  SibSp  Parch   Age Cabin
# 339          340      0      0  45.0     T
#      Survived              Name Last_name  Fare  Ticket  PassengerId  SibSp  \
# 209       1.0  Blank, Mr. Henry     Blank  31.0  112277          210      0
#
#      Parch   Age Cabin
# 209      0  40.0   A31
#     Survived                      Name Last_name   Fare  Ticket  PassengerId  \
# 11       1.0  Bonnell, Miss. Elizabeth   Bonnell  26.55  113783           12
#
#     SibSp  Parch   Age Cabin
# 11      0      0  58.0  C103
#      Survived                     Name Last_name      Fare Ticket  \
# 400       NaN  Bonnell, Miss. Caroline   Bonnell  164.8667  36928
#
#      PassengerId  SibSp  Parch   Age Cabin
# 400         1292      0      0  30.0    C7
#      Survived                      Name Last_name   Fare  Ticket  PassengerId  \
# 158       NaN  Borebank, Mr. John James  Borebank  26.55  110489         1050
#
#      SibSp  Parch   Age Cabin
# 158      0      0  42.0   D22
#      Survived                       Name    Last_name    Fare  Ticket  \
# 628       0.0  Bostandyeff, Mr. Guentcho  Bostandyeff  7.8958  349224
#
#      PassengerId  SibSp  Parch   Age Cabin
# 628          629      0      0  26.0   NaN
#      Survived                        Name Last_name  Fare  Ticket  \
# 346       NaN  Botsford, Mr. William Hull  Botsford  13.0  237670
#
#      PassengerId  SibSp  Parch   Age Cabin
# 346         1238      0      0  26.0   NaN
#      Survived               Name Last_name   Fare Ticket  PassengerId  SibSp  \
# 598       0.0  Boulos, Mr. Hanna    Boulos  7.225   2664          599      0
#
#      Parch   Age Cabin
# 598      0  42.0   NaN
#      Survived                           Name Last_name     Fare Ticket  \
# 140       0.0  Boulos, Mrs. Joseph (Sultana)    Boulos  15.2458   2678
# 852       0.0        Boulos, Miss. Nourelain    Boulos  15.2458   2678
# 80        NaN           Boulos, Master. Akar    Boulos  15.2458   2678
#
#      PassengerId  SibSp  Parch   Age Cabin
# 140          141      0      2  35.0   NaN
# 852          853      1      1   9.0   NaN
# 80           972      1      1   6.0   NaN
#      Survived                Name Last_name  Fare  Ticket  PassengerId  SibSp  \
# 593       0.0  Bourke, Miss. Mary    Bourke  7.75  364848          594      0
#
#      Parch  Age Cabin
# 593      2  9.0   NaN
#      Survived                           Name Last_name  Fare  Ticket  \
# 188       0.0               Bourke, Mr. John    Bourke  15.5  364849
# 657       0.0  Bourke, Mrs. John (Catherine)    Bourke  15.5  364849
#
#      PassengerId  SibSp  Parch   Age Cabin
# 188          189      1      1  40.0   NaN
# 657          658      1      1  32.0   NaN
#      Survived                         Name Last_name  Fare Ticket  \
# 624       0.0  Bowen, Mr. David John "Dai"     Bowen  16.1  54636
#
#      PassengerId  SibSp  Parch   Age Cabin
# 624          625      0      0  21.0   NaN
#      Survived                      Name Last_name     Fare    Ticket  \
# 375       NaN  Bowen, Miss. Grace Scott     Bowen  262.375  PC 17608
#
#      PassengerId  SibSp  Parch   Age Cabin
# 375         1267      0      0  45.0   NaN
#      Survived                  Name Last_name  Fare  Ticket  PassengerId  \
# 128       NaN  Bowenur, Mr. Solomon   Bowenur  13.0  211535         1020
#
#      SibSp  Parch   Age Cabin
# 128      0      0  42.0   NaN
#      Survived                         Name Last_name  Fare  Ticket  \
# 356       1.0  Bowerman, Miss. Elsie Edith  Bowerman  55.0  113505
#
#      PassengerId  SibSp  Parch   Age Cabin
# 356          357      0      1  22.0   E33
#      Survived                  Name Last_name  Fare  Ticket  PassengerId  \
# 221       0.0  Bracken, Mr. James H   Bracken  13.0  220367          222
#
#      SibSp  Parch   Age Cabin
# 221      0      0  27.0   NaN
#     Survived                          Name Last_name   Fare  Ticket  \
# 63       NaN  Bradley, Miss. Bridget Delia   Bradley  7.725  334914
#
#     PassengerId  SibSp  Parch   Age Cabin
# 63          955      0      0  22.0   NaN
#      Survived                                           Name Last_name   Fare  \
# 507       1.0  Bradley, Mr. George ("George Arthur Brayton")   Bradley  26.55
#
#      Ticket  PassengerId  SibSp  Parch   Age Cabin
# 507  111427          508      0      0  42.0   NaN
#     Survived                     Name Last_name  Fare  Ticket  PassengerId  \
# 28       NaN  Brady, Mr. John Bertram     Brady  30.5  113054          920
#
#     SibSp  Parch   Age Cabin
# 28      0      0  41.0   A21
#     Survived                          Name Last_name    Fare  Ticket  \
# 98       NaN  Braf, Miss. Elin Ester Maria      Braf  7.8542  347471
#
#     PassengerId  SibSp  Parch   Age Cabin
# 98          990      0      0  20.0   NaN
#      Survived                Name Last_name     Fare    Ticket  PassengerId  \
# 166       NaN  Brandeis, Mr. Emil  Brandeis  50.4958  PC 17591         1058
#
#      SibSp  Parch   Age Cabin
# 166      0      0  48.0   B10
#      Survived                       Name Last_name    Fare Ticket  \
# 477       0.0  Braund, Mr. Lewis Richard    Braund  7.0458   3460
#
#      PassengerId  SibSp  Parch   Age Cabin
# 477          478      1      0  29.0   NaN
#    Survived                     Name Last_name  Fare     Ticket  PassengerId  \
# 0       0.0  Braund, Mr. Owen Harris    Braund  7.25  A/5 21171            1
#
#    SibSp  Parch   Age Cabin
# 0      1      0  22.0   NaN
#      Survived                       Name Last_name  Fare  Ticket  PassengerId  \
# 766       0.0  Brewe, Dr. Arthur Jackson     Brewe  39.6  112379          767
#
#      SibSp  Parch   Age Cabin
# 766      0      0  53.0   NaN
#      Survived                      Name Last_name    Fare  Ticket  \
# 126       NaN  Brobeck, Mr. Karl Rudolf   Brobeck  7.7958  350045
#
#      PassengerId  SibSp  Parch   Age Cabin
# 126         1018      0      0  22.0   NaN
#      Survived                             Name    Last_name  Fare  Ticket  \
# 614       0.0  Brocklebank, Mr. William Alfred  Brocklebank  8.05  364512
#
#      PassengerId  SibSp  Parch   Age Cabin
# 614          615      0      0  35.0   NaN
#      Survived                           Name Last_name  Fare  Ticket  \
# 345       1.0  Brown, Miss. Amelia "Mildred"     Brown  13.0  248733
#
#      PassengerId  SibSp  Parch   Age Cabin
# 345          346      0      0  24.0   F33
#      Survived                                       Name Last_name     Fare  \
# 194       1.0  Brown, Mrs. James Joseph (Margaret Tobin)     Brown  27.7208
#
#        Ticket  PassengerId  SibSp  Parch   Age Cabin
# 194  PC 17610          195      0      0  44.0    B4
#      Survived                                               Name Last_name  \
# 670       1.0  Brown, Mrs. Thomas William Solomon (Elizabeth ...     Brown
# 684       0.0                  Brown, Mr. Thomas William Solomon     Brown
# 175       NaN                          Brown, Miss. Edith Eileen     Brown
#
#      Fare Ticket  PassengerId  SibSp  Parch   Age Cabin
# 670  39.0  29750          671      1      1  40.0   NaN
# 684  39.0  29750          685      1      1  60.0   NaN
# 175  39.0  29750         1067      0      2  15.0   NaN
#      Survived                                            Name Last_name  \
# 356       NaN  Brown, Mrs. John Murray (Caroline Lane Lamson)     Brown
#
#         Fare Ticket  PassengerId  SibSp  Parch   Age Cabin
# 356  51.4792  11769         1248      2      0  59.0  C101
#      Survived                                 Name Last_name  Fare  Ticket  \
# 728       0.0      Bryhl, Mr. Kurt Arnold Gottfrid     Bryhl  26.0  236853
# 275       NaN  Bryhl, Miss. Dagmar Jenny Ingeborg      Bryhl  26.0  236853
#
#      PassengerId  SibSp  Parch   Age Cabin
# 728          729      1      0  25.0   NaN
# 275         1167      1      0  20.0   NaN
#      Survived                      Name Last_name    Fare  Ticket  \
# 113       NaN  Buckley, Miss. Katherine   Buckley  7.2833  329944
#
#      PassengerId  SibSp  Parch   Age Cabin
# 113         1005      0      0  18.5   NaN
#      Survived                 Name Last_name    Fare  Ticket  PassengerId  \
# 106       NaN  Buckley, Mr. Daniel   Buckley  7.8208  330920          998
#
#      SibSp  Parch   Age Cabin
# 106      0      0  21.0   NaN
#     Survived                                             Name Last_name  \
# 48       NaN  Bucknell, Mrs. William Robert (Emma Eliza Ward)  Bucknell
#
#        Fare Ticket  PassengerId  SibSp  Parch   Age Cabin
# 48  76.2917  11813          940      0      0  60.0   D15
#      Survived                 Name Last_name  Fare  Ticket  PassengerId  \
# 143       0.0  Burke, Mr. Jeremiah     Burke  6.75  365222          144
#
#      SibSp  Parch   Age Cabin
# 143      0      0  19.0   NaN
#     Survived                     Name Last_name    Fare  Ticket  PassengerId  \
# 66       NaN  Burns, Miss. Mary Delia     Burns  7.8792  330963          958
#
#     SibSp  Parch   Age Cabin
# 66      0      0  18.0   NaN
#      Survived                             Name Last_name   Fare Ticket  \
# 337       1.0  Burns, Miss. Elizabeth Margaret     Burns  134.5  16966
#
#      PassengerId  SibSp  Parch   Age Cabin
# 337          338      0      0  41.0   E40
#      Survived              Name Last_name  Fare Ticket  PassengerId  SibSp  \
# 387       1.0  Buss, Miss. Kate      Buss  13.0  27849          388      0
#
#      Parch   Age Cabin
# 387      0  36.0   NaN
#      Survived                         Name Last_name  Fare  Ticket  \
# 666       0.0  Butler, Mr. Reginald Fenton    Butler  13.0  234686
#
#      PassengerId  SibSp  Parch   Age Cabin
# 666          667      0      0  25.0   NaN
#      Survived                               Name Last_name   Fare  Ticket  \
# 536       0.0  Butt, Major. Archibald Willingham      Butt  26.55  113050
#
#      PassengerId  SibSp  Parch   Age Cabin
# 536          537      0      0  45.0   B38
#      Survived                               Name Last_name  Fare  Ticket  \
# 149       0.0  Byles, Rev. Thomas Roussel Davids     Byles  13.0  244310
#
#      PassengerId  SibSp  Parch   Age Cabin
# 149          150      0      0  42.0   NaN
#      Survived                      Name Last_name  Fare  Ticket  PassengerId  \
# 865       1.0  Bystrom, Mrs. (Karolina)   Bystrom  13.0  236852          866
#
#      SibSp  Parch   Age Cabin
# 865      0      0  42.0   NaN
#      Survived                  Name Last_name    Fare  Ticket  PassengerId  \
# 471       0.0       Cacic, Mr. Luka     Cacic  8.6625  315089          472
# 534       0.0   Cacic, Miss. Marija     Cacic  8.6625  315084          535
# 37        NaN    Cacic, Miss. Manda     Cacic  8.6625  315087          929
# 310       NaN  Cacic, Mr. Jego Grga     Cacic  8.6625  315091         1202
#
#      SibSp  Parch   Age Cabin
# 471      0      0  38.0   NaN
# 534      0      0  30.0   NaN
# 37       0      0  21.0   NaN
# 310      0      0  18.0   NaN
#      Survived                   Name Last_name  Fare  Ticket  PassengerId  \
# 270       0.0  Cairns, Mr. Alexander    Cairns  31.0  113798          271
#
#      SibSp  Parch   Age Cabin
# 270      0      0  42.0   NaN
#      Survived                               Name   Last_name     Fare  \
# 707       1.0  Calderhead, Mr. Edward Pennington  Calderhead  26.2875
#
#        Ticket  PassengerId  SibSp  Parch   Age Cabin
# 707  PC 17476          708      0      0  42.0   E24
#      Survived                                               Name Last_name  \
# 78        1.0                      Caldwell, Master. Alden Gates  Caldwell
# 323       1.0  Caldwell, Mrs. Albert Francis (Sylvia Mae Harb...  Caldwell
# 7         NaN                       Caldwell, Mr. Albert Francis  Caldwell
#
#      Fare  Ticket  PassengerId  SibSp  Parch    Age Cabin
# 78   29.0  248738           79      0      2   0.83   NaN
# 323  29.0  248738          324      1      1  22.00   NaN
# 7    29.0  248738          899      1      1  26.00   NaN
#      Survived              Name Last_name    Fare  Ticket  PassengerId  SibSp  \
# 163       0.0   Calic, Mr. Jovo     Calic  8.6625  315093          164      0
# 500       0.0  Calic, Mr. Petar     Calic  8.6625  315086          501      0
#
#      Parch   Age Cabin
# 163      0  17.0   NaN
# 500      0  17.0   NaN
#      Survived                        Name Last_name  Fare        Ticket  \
# 211       1.0  Cameron, Miss. Clear Annie   Cameron  21.0  F.C.C. 13528
#
#      PassengerId  SibSp  Parch   Age Cabin
# 211          212      0      0  35.0   NaN
#      Survived                   Name Last_name  Fare  Ticket  PassengerId  \
# 466       0.0  Campbell, Mr. William  Campbell   0.0  239853          467
#
#      SibSp  Parch   Age Cabin
# 466      0      0  42.0   NaN
#      Survived                  Name Last_name  Fare  Ticket  PassengerId  \
# 501       0.0   Canavan, Miss. Mary   Canavan  7.75  364846          502
# 388       NaN  Canavan, Mr. Patrick   Canavan  7.75  364858         1280
#
#      SibSp  Parch   Age Cabin
# 501      0      0  21.0   NaN
# 388      0      0  21.0   NaN
#      Survived                                              Name Last_name  \
# 224       NaN  Candee, Mrs. Edward (Helen Churchill Hungerford)    Candee
#
#         Fare    Ticket  PassengerId  SibSp  Parch   Age Cabin
# 224  27.4458  PC 17606         1116      0      0  53.0   NaN
#     Survived                      Name Last_name  Fare      Ticket  \
# 37       0.0  Cann, Mr. Ernest Charles      Cann  8.05  A./5. 2152
#
#     PassengerId  SibSp  Parch   Age Cabin
# 37           38      0      0  21.0   NaN
#      Survived                              Name Last_name     Fare Ticket  \
# 578       0.0  Caram, Mrs. Joseph (Maria Elias)     Caram  14.4583   2689
# 366       NaN                 Caram, Mr. Joseph     Caram  14.4583   2689
#
#      PassengerId  SibSp  Parch   Age Cabin
# 578          579      1      0  35.0   NaN
# 366         1258      1      0  42.0   NaN
#      Survived                   Name Last_name  Fare Ticket  PassengerId  \
# 191       0.0  Carbines, Mr. William  Carbines  13.0  28424          192
#
#      SibSp  Parch   Age Cabin
# 191      0      0  19.0   NaN
#      Survived                                               Name Last_name  \
# 679       1.0                 Cardeza, Mr. Thomas Drake Martinez   Cardeza
# 343       NaN  Cardeza, Mrs. James Warburton Martinez (Charlo...   Cardeza
#
#          Fare    Ticket  PassengerId  SibSp  Parch   Age        Cabin
# 679  512.3292  PC 17755          680      0      1  36.0  B51 B53 B55
# 343  512.3292  PC 17755         1235      0      1  58.0  B51 B53 B55
#      Survived                      Name Last_name  Fare Ticket  PassengerId  \
# 872       0.0  Carlsson, Mr. Frans Olof  Carlsson   5.0    695          873
#
#      SibSp  Parch   Age        Cabin
# 872      0      0  33.0  B51 B53 B55
#      Survived                          Name Last_name    Fare  Ticket  \
# 756       0.0  Carlsson, Mr. August Sigfrid  Carlsson  7.7958  350042
#
#      PassengerId  SibSp  Parch   Age Cabin
# 756          757      0      0  28.0   NaN
#      Survived                       Name Last_name    Fare  Ticket  \
# 135       NaN  Carlsson, Mr. Carl Robert  Carlsson  7.8542  350409
#
#      PassengerId  SibSp  Parch   Age Cabin
# 135         1027      0      0  24.0   NaN
#      Survived                       Name Last_name  Fare  Ticket  PassengerId  \
# 208       1.0  Carr, Miss. Helen "Ellen"      Carr  7.75  367231          209
# 313       NaN        Carr, Miss. Jeannie      Carr  7.75  368364         1205
#
#      SibSp  Parch   Age Cabin
# 208      0      0  16.0   NaN
# 313      0      0  37.0   NaN
#      Survived                     Name Last_name  Fare  Ticket  PassengerId  \
# 83        0.0  Carrau, Mr. Francisco M    Carrau  47.1  113059           84
# 403       NaN   Carrau, Mr. Jose Pedro    Carrau  47.1  113059         1295
#
#      SibSp  Parch   Age Cabin
# 83       0      0  28.0   NaN
# 403      0      0  17.0   NaN
#      Survived                                           Name Last_name  Fare  \
# 249       0.0                  Carter, Rev. Ernest Courtenay    Carter  26.0
# 854       0.0  Carter, Mrs. Ernest Courtenay (Lilian Hughes)    Carter  26.0
#
#      Ticket  PassengerId  SibSp  Parch   Age Cabin
# 249  244252          250      1      0  54.0   NaN
# 854  244252          855      1      0  44.0   NaN
#      Survived                                       Name Last_name   Fare  \
# 390       1.0                 Carter, Mr. William Ernest    Carter  120.0
# 435       1.0                  Carter, Miss. Lucile Polk    Carter  120.0
# 763       1.0  Carter, Mrs. William Ernest (Lucile Polk)    Carter  120.0
# 802       1.0        Carter, Master. William Thornton II    Carter  120.0
#
#      Ticket  PassengerId  SibSp  Parch   Age    Cabin
# 390  113760          391      1      2  36.0  B96 B98
# 435  113760          436      1      2  14.0  B96 B98
# 763  113760          764      1      2  36.0  B96 B98
# 802  113760          803      1      2  11.0  B96 B98
#      Survived                     Name Last_name  Fare  Ticket  PassengerId  \
# 123       NaN  Carver, Mr. Alfred John    Carver  7.25  392095         1015
#
#      SibSp  Parch   Age Cabin
# 123      0      0  28.0   NaN
#     Survived                    Name Last_name  Fare Ticket  PassengerId  \
# 82       NaN  Case, Mr. Howard Brown      Case  26.0  19924          974
#
#     SibSp  Parch   Age Cabin
# 82      0      0  49.0   NaN
#      Survived                                               Name  Last_name  \
# 168       NaN  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...  Cassebeer
#
#         Fare Ticket  PassengerId  SibSp  Parch   Age Cabin
# 168  27.7208  17770         1060      0      0  35.0   NaN
#      Survived                                               Name  Last_name  \
# 741       0.0                      Cavendish, Mr. Tyrell William  Cavendish
# 96        NaN  Cavendish, Mrs. Tyrell William (Julia Florence...  Cavendish
#
#       Fare Ticket  PassengerId  SibSp  Parch   Age Cabin
# 741  78.85  19877          742      1      0  36.0   C46
# 96   78.85  19877          988      1      0  76.0   C46
#     Survived                    Name Last_name  Fare  Ticket  PassengerId  \
# 89       0.0  Celotti, Mr. Francesco   Celotti  8.05  343275           90
#
#     SibSp  Parch   Age Cabin
# 89      0      0  24.0   NaN
#     Survived                                               Name Last_name  \
# 92       0.0                        Chaffee, Mr. Herbert Fuller   Chaffee
# 14       NaN  Chaffee, Mrs. Herbert Fuller (Carrie Constance...   Chaffee
#
#       Fare       Ticket  PassengerId  SibSp  Parch   Age Cabin
# 92  61.175  W.E.P. 5734           93      1      0  46.0   E31
# 14  61.175  W.E.P. 5734          906      1      0  47.0   E31
#      Survived                                            Name Last_name  Fare  \
# 724       1.0                   Chambers, Mr. Norman Campbell  Chambers  53.1
# 809       1.0  Chambers, Mrs. Norman Campbell (Bertha Griggs)  Chambers  53.1
#
#      Ticket  PassengerId  SibSp  Parch   Age Cabin
# 724  113806          725      1      0  27.0    E8
# 809  113806          810      1      0  33.0    E8
#      Survived                        Name Last_name  Fare  Ticket  \
# 695       0.0  Chapman, Mr. Charles Henry   Chapman  13.5  248731
#
#      PassengerId  SibSp  Parch   Age Cabin
# 695          696      0      0  52.0   NaN
#      Survived                                             Name Last_name  \
# 594       0.0                          Chapman, Mr. John Henry   Chapman
# 119       NaN  Chapman, Mrs. John Henry (Sara Elizabeth Lawry)   Chapman
#
#      Fare       Ticket  PassengerId  SibSp  Parch   Age Cabin
# 594  26.0  SC/AH 29037          595      1      0  37.0   NaN
# 119  26.0  SC/AH 29037         1011      1      0  29.0   NaN
#      Survived                 Name Last_name    Fare      Ticket  PassengerId  \
# 421       0.0  Charters, Mr. David  Charters  7.7333  A/5. 13032          422
#
#      SibSp  Parch   Age Cabin
# 421      0      0  21.0   NaN
#     Survived                         Name   Last_name     Fare    Ticket  \
# 59       NaN  Chaudanson, Miss. Victorine  Chaudanson  262.375  PC 17608
#
#     PassengerId  SibSp  Parch   Age Cabin
# 59          951      0      0  36.0   B61
#      Survived                  Name Last_name  Fare  Ticket  PassengerId  \
# 257       1.0  Cherry, Miss. Gladys    Cherry  86.5  110152          258
#
#      SibSp  Parch   Age Cabin
# 257      0      0  30.0   B77
#     Survived                      Name Last_name  Fare    Ticket  PassengerId  \
# ...
# 278  CA 31352         1170      1      0  30.0   NaN
# 362  CA 31352         1254      0      0  31.0   NaN
#      Survived                         Name Last_name  Fare      Ticket  \
# 267       NaN  Warren, Mr. Charles William    Warren  7.55  C.A. 49867
#
#      PassengerId  SibSp  Parch   Age Cabin
# 267         1159      0      0  42.0   NaN
#      Survived                                              Name Last_name  \
# 366       1.0  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)    Warren
# 236       NaN                          Warren, Mr. Frank Manley    Warren
#
#       Fare  Ticket  PassengerId  SibSp  Parch   Age Cabin
# 366  75.25  110813          367      1      0  60.0   D37
# 236  75.25  110813         1128      1      0  64.0   D37
#      Survived                        Name Last_name  Fare  Ticket  \
# 674       0.0  Watson, Mr. Ennis Hastings    Watson   0.0  239856
#
#      PassengerId  SibSp  Parch   Age Cabin
# 674          675      0      0  42.0   NaN
#      Survived                                               Name Last_name  \
# 161       1.0  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...      Watt
# 120       NaN                               Watt, Miss. Bertha J      Watt
#
#       Fare      Ticket  PassengerId  SibSp  Parch   Age Cabin
# 161  15.75  C.A. 33595          162      0      0  40.0   NaN
# 120  15.75  C.A. 33595         1012      0      0  12.0   NaN
#      Survived               Name Last_name  Fare            Ticket  \
# 511       0.0  Webber, Mr. James    Webber  8.05  SOTON/OQ 3101316
#
#      PassengerId  SibSp  Parch   Age Cabin
# 511          512      0      0  42.0   NaN
#      Survived                 Name Last_name  Fare Ticket  PassengerId  SibSp  \
# 123       1.0  Webber, Miss. Susan    Webber  13.0  27267          124      0
#
#      Parch   Age Cabin
# 123      0  32.5  E101
#      Survived             Name Last_name   Fare  Ticket  PassengerId  SibSp  \
# 694       0.0  Weir, Col. John      Weir  26.55  113800          695      0
#
#      Parch   Age Cabin
# 694      0  60.0   NaN
#      Survived                                           Name Last_name  Fare  \
# 133       1.0  Weisz, Mrs. Leopold (Mathilde Francoise Pede)     Weisz  26.0
# 101       NaN                             Weisz, Mr. Leopold     Weisz  26.0
#
#      Ticket  PassengerId  SibSp  Parch   Age Cabin
# 133  228414          134      1      0  29.0   NaN
# 101  228414          993      1      0  27.0   NaN
#      Survived                                               Name Last_name  \
# 750       1.0                                  Wells, Miss. Joan     Wells
# 89        NaN                        Wells, Master. Ralph Lester     Wells
# 262       NaN  Wells, Mrs. Arthur Henry (Addie" Dart Trevaskis)"     Wells
#
#      Fare Ticket  PassengerId  SibSp  Parch   Age Cabin
# 750  23.0  29103          751      1      1   4.0   NaN
# 89   23.0  29103          981      1      1   2.0   NaN
# 262  23.0  29103         1154      0      2  29.0   NaN
#      Survived                 Name Last_name  Fare  Ticket  PassengerId  \
# 254       NaN  Wenzel, Mr. Linhart    Wenzel   9.5  345775         1146
#
#      SibSp  Parch   Age Cabin
# 254      0      0  32.5   NaN
#      Survived                                     Name Last_name   Fare  \
# 58        1.0             West, Miss. Constance Mirium      West  27.75
# 450       0.0                    West, Mr. Edwy Arthur      West  27.75
# 472       1.0  West, Mrs. Edwy Arthur (Ada Mary Worth)      West  27.75
# 250       NaN                    West, Miss. Barbara J      West  27.75
#
#          Ticket  PassengerId  SibSp  Parch    Age Cabin
# 58   C.A. 34651           59      1      2   5.00   NaN
# 450  C.A. 34651          451      1      2  36.00   NaN
# 472  C.A. 34651          473      1      2  33.00   NaN
# 250  C.A. 34651         1142      1      2   0.92   NaN
#      Survived                                             Name Last_name  \
# 347       NaN  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)    Whabee
#
#        Fare Ticket  PassengerId  SibSp  Parch   Age Cabin
# 347  7.2292   2688         1239      0      0  38.0   NaN
#     Survived                   Name Last_name  Fare      Ticket  PassengerId  \
# 33       0.0  Wheadon, Mr. Edward H   Wheadon  10.5  C.A. 24579           34
#
#     SibSp  Parch   Age Cabin
# 33      0      0  66.0   NaN
#      Survived                            Name Last_name    Fare  \
# 384       NaN  Wheeler, Mr. Edwin Frederick""   Wheeler  12.875
#
#             Ticket  PassengerId  SibSp  Parch   Age Cabin
# 384  SC/PARIS 2159         1276      0      0  42.0   NaN
#      Survived                         Name Last_name     Fare Ticket  \
# 102       0.0    White, Mr. Richard Frasar     White  77.2875  35281
# 124       0.0  White, Mr. Percival Wayland     White  77.2875  35281
#
#      PassengerId  SibSp  Parch   Age Cabin
# 102          103      0      1  21.0   D26
# 124          125      0      1  54.0   D26
#      Survived                                   Name Last_name      Fare  \
# 314       NaN  White, Mrs. John Stuart (Ella Holmes)     White  135.6333
#
#        Ticket  PassengerId  SibSp  Parch   Age Cabin
# 314  PC 17760         1206      0      0  55.0   C32
#      Survived                                        Name Last_name      Fare  \
# 318       1.0                    Wick, Miss. Mary Natalie      Wick  164.8667
# 856       1.0  Wick, Mrs. George Dennick (Mary Hitchcock)      Wick  164.8667
# 217       NaN                    Wick, Mr. George Dennick      Wick  164.8667
#
#     Ticket  PassengerId  SibSp  Parch   Age Cabin
# 318  36928          319      0      2  31.0    C7
# 856  36928          857      1      1  45.0   NaN
# 217  36928         1109      1      1  57.0   NaN
#      Survived                              Name Last_name  Fare  Ticket  \
# 406       0.0  Widegren, Mr. Carl/Charles Peter  Widegren  7.75  347064
#
#      PassengerId  SibSp  Parch   Age Cabin
# 406          407      0      0  51.0   NaN
#      Survived                                          Name Last_name   Fare  \
# 377       0.0                     Widener, Mr. Harry Elkins   Widener  211.5
# 218       NaN  Widener, Mrs. George Dunton (Eleanor Elkins)   Widener  211.5
# 407       NaN                    Widener, Mr. George Dunton   Widener  211.5
#
#      Ticket  PassengerId  SibSp  Parch   Age Cabin
# 377  113503          378      0      2  27.0   C82
# 218  113503         1110      1      1  50.0   C80
# 407  113503         1299      1      1  50.0   C80
#      Survived                       Name Last_name    Fare   Ticket  \
# 371       0.0  Wiklund, Mr. Jakob Alfred   Wiklund  6.4958  3101267
# 232       NaN    Wiklund, Mr. Karl Johan   Wiklund  6.4958  3101266
#
#      PassengerId  SibSp  Parch   Age Cabin
# 371          372      1      0  18.0   NaN
# 232         1124      1      0  21.0   NaN
#      Survived                   Name Last_name  Fare  Ticket  PassengerId  \
# 673       1.0  Wilhelms, Mr. Charles  Wilhelms  13.0  244270          674
#
#      SibSp  Parch   Age Cabin
# 673      0      0  31.0   NaN
#    Survived                              Name Last_name  Fare  Ticket  \
# 1       NaN  Wilkes, Mrs. James (Ellen Needs)    Wilkes   7.0  363272
#
#    PassengerId  SibSp  Parch   Age Cabin
# 1          893      1      0  47.0   NaN
#      Survived                      Name Last_name   Fare  Ticket  PassengerId  \
# 231       NaN  Willard, Miss. Constance   Willard  26.55  113795         1123
#
#      SibSp  Parch   Age Cabin
# 231      0      0  21.0   NaN
#      Survived                              Name Last_name    Fare Ticket  \
# 108       NaN  Willer, Mr. Aaron (Abi Weller")"    Willer  8.7125   3410
#
#      PassengerId  SibSp  Parch   Age Cabin
# 108         1000      0      0  42.0   NaN
#      Survived                Name Last_name  Fare         Ticket  PassengerId  \
# 648       0.0  Willey, Mr. Edward    Willey  7.55  S.O./P.P. 751          649
#
#      SibSp  Parch   Age Cabin
# 648      0      0  42.0   NaN
#      Survived                               Name Last_name  Fare    Ticket  \
# 304       0.0  Williams, Mr. Howard Hugh "Harry"  Williams  8.05  A/5 2466
#
#      PassengerId  SibSp  Parch   Age Cabin
# 304          305      0      0  42.0   NaN
#     Survived                          Name Last_name  Fare  Ticket  \
# 17       1.0  Williams, Mr. Charles Eugene  Williams  13.0  244373
#
#     PassengerId  SibSp  Parch   Age Cabin
# 17           18      0      0  42.0   NaN
#      Survived                  Name Last_name  Fare Ticket  PassengerId  \
# 735       0.0  Williams, Mr. Leslie  Williams  16.1  54636          736
#
#      SibSp  Parch   Age Cabin
# 735      0      0  28.5   NaN
#      Survived                             Name Last_name     Fare    Ticket  \
# 155       0.0      Williams, Mr. Charles Duane  Williams  61.3792  PC 17597
# 23        NaN  Williams, Mr. Richard Norris II  Williams  61.3792  PC 17597
#
#      PassengerId  SibSp  Parch   Age Cabin
# 155          156      0      1  51.0   NaN
# 23           915      0      1  21.0   NaN
#      Survived                                    Name         Last_name  Fare  \
# 351       0.0  Williams-Lambert, Mr. Fletcher Fellows  Williams-Lambert  35.0
#
#      Ticket  PassengerId  SibSp  Parch   Age Cabin
# 351  113510          352      0      0  42.0  C128
#      Survived                       Name Last_name   Fare Ticket  PassengerId  \
# 371       NaN  Wilson, Miss. Helen Alice    Wilson  134.5  16966         1263
#
#      SibSp  Parch   Age    Cabin
# 371      0      0  31.0  E39 E41
#      Survived                 Name Last_name  Fare            Ticket  \
# 491       0.0  Windelov, Mr. Einar  Windelov  7.25  SOTON/OQ 3101317
#
#      PassengerId  SibSp  Parch   Age Cabin
# 491          492      0      0  21.0   NaN
#    Survived              Name Last_name    Fare  Ticket  PassengerId  SibSp  \
# 3       NaN  Wirz, Mr. Albert      Wirz  8.6625  315154          895      0
#
#    Parch   Age Cabin
# 3      0  27.0   NaN
#      Survived                    Name Last_name  Fare      Ticket  \
# 425       0.0  Wiseman, Mr. Phillippe   Wiseman  7.25  A/4. 34244
#
#      PassengerId  SibSp  Parch   Age Cabin
# 425          426      0      0  42.0   NaN
#      Survived                       Name     Last_name  Fare  Ticket  \
# 294       NaN  Wittevrongel, Mr. Camille  Wittevrongel   9.5  345771
#
#      PassengerId  SibSp  Parch   Age Cabin
# 294         1186      0      0  36.0   NaN
#     Survived               Name Last_name  Fare Ticket  PassengerId  SibSp  \
# 55       1.0  Woolner, Mr. Hugh   Woolner  35.5  19947           56      0
#
#     Parch   Age Cabin
# 55      0  42.0   C52
#      Survived                  Name Last_name  Fare  Ticket  PassengerId  \
# 162       NaN  Wright, Miss. Marion    Wright  13.5  220844         1054
#
#      SibSp  Parch   Age Cabin
# 162      0      0  26.0   NaN
#      Survived                Name Last_name   Fare  Ticket  PassengerId  \
# 555       0.0  Wright, Mr. George    Wright  26.55  113807          556
#
#      SibSp  Parch   Age Cabin
# 555      0      0  62.0   NaN
#      Survived                                     Name Last_name     Fare  \
# 620       0.0                      Yasbeck, Mr. Antoni   Yasbeck  14.4542
# 830       1.0  Yasbeck, Mrs. Antoni (Selini Alexander)   Yasbeck  14.4542
#
#     Ticket  PassengerId  SibSp  Parch   Age Cabin
# 620   2659          621      1      0  27.0   NaN
# 830   2659          831      1      0  15.0   NaN
#      Survived                      Name Last_name      Fare    Ticket  \
# 325       1.0  Young, Miss. Marie Grice     Young  135.6333  PC 17760
#
#      PassengerId  SibSp  Parch   Age Cabin
# 325          326      0      0  36.0   C32
#      Survived                  Name Last_name   Fare Ticket  PassengerId  \
# 203       0.0  Youseff, Mr. Gerious   Youseff  7.225   2628          204
#
#      SibSp  Parch   Age Cabin
# 203      0      0  45.5   NaN
#      Survived               Name Last_name   Fare Ticket  PassengerId  SibSp  \
# 354       0.0  Yousif, Mr. Wazli    Yousif  7.225   2647          355      0
#
#      Parch   Age Cabin
# 354      0  42.0   NaN
#      Survived                   Name Last_name     Fare Ticket  PassengerId  \
# 495       0.0  Yousseff, Mr. Gerious  Yousseff  14.4583   2627          496
#
#      SibSp  Parch   Age Cabin
# 495      0      0  42.0   NaN
#      Survived                                    Name Last_name  Fare  Ticket  \
# 199       0.0  Yrois, Miss. Henriette ("Mrs Harbeck")     Yrois  13.0  248747
#
#      PassengerId  SibSp  Parch   Age Cabin
# 199          200      0      0  24.0   NaN
#      Survived                   Name Last_name     Fare Ticket  PassengerId  \
# 111       0.0   Zabour, Miss. Hileni    Zabour  14.4542   2665          112
# 240       0.0  Zabour, Miss. Thamine    Zabour  14.4542   2665          241
#
#      SibSp  Parch   Age Cabin
# 111      1      0  14.5   NaN
# 240      1      0   9.0   NaN
#      Survived                       Name Last_name   Fare Ticket  PassengerId  \
# 136       NaN  Zakarian, Mr. Mapriededer  Zakarian  7.225   2656         1028
# 171       NaN        Zakarian, Mr. Ortin  Zakarian  7.225   2670         1063
#
#      SibSp  Parch   Age Cabin
# 136      0      0  26.5   NaN
# 171      0      0  27.0   NaN
#      Survived                Name  Last_name   Fare  Ticket  PassengerId  \
# 422       0.0  Zimmerman, Mr. Leo  Zimmerman  7.875  315082          423
#
#      SibSp  Parch   Age Cabin
# 422      0      0  29.0   NaN
#      Survived                        Name Last_name  Fare  Ticket  \
# 336       NaN  de Brito, Mr. Jose Joaquim  de Brito  13.0  244360
#
#      PassengerId  SibSp  Parch   Age Cabin
# 336         1228      0      0  32.0   NaN
#      Survived                                          Name       Last_name  \
# 559       1.0  de Messemaeker, Mrs. Guillaume Joseph (Emma)  de Messemaeker
# 260       NaN          de Messemaeker, Mr. Guillaume Joseph  de Messemaeker
#
#      Fare  Ticket  PassengerId  SibSp  Parch   Age Cabin
# 559  17.4  345572          560      1      0  36.0   NaN
# 260  17.4  345572         1152      1      0  36.5   NaN
#      Survived                     Name  Last_name  Fare  Ticket  PassengerId  \
# 286       1.0  de Mulder, Mr. Theodore  de Mulder   9.5  345774          287
#
#      SibSp  Parch   Age Cabin
# 286      0      0  30.0   NaN
#      Survived                       Name      Last_name  Fare  Ticket  \
# 282       0.0  de Pelsmaeker, Mr. Alfons  de Pelsmaeker   9.5  345778
#
#      PassengerId  SibSp  Parch   Age Cabin
# 282          283      0      0  16.0   NaN
#      Survived                                           Name  Last_name  \
# 361       0.0                      del Carlo, Mr. Sebastiano  del Carlo
# 15        NaN  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  del Carlo
#
#         Fare         Ticket  PassengerId  SibSp  Parch   Age Cabin
# 361  27.7208  SC/PARIS 2167          362      1      0  29.0   NaN
# 15   27.7208  SC/PARIS 2167          907      1      0  24.0   NaN
#      Survived                                 Name     Last_name  Fare  \
# 153       0.0      van Billiard, Mr. Austin Blyler  van Billiard  14.5
# 192       NaN    van Billiard, Master. Walter John  van Billiard  14.5
# 344       NaN  van Billiard, Master. James William  van Billiard  14.5
#
#        Ticket  PassengerId  SibSp  Parch   Age Cabin
# 153  A/5. 851          154      0      2  40.5   NaN
# 192  A/5. 851         1084      1      1  11.5   NaN
# 344  A/5. 851         1236      1      1   6.0   NaN
#      Survived                         Name      Last_name  Fare  Ticket  \
# 868       0.0  van Melkebeke, Mr. Philemon  van Melkebeke   9.5  345777
#
#      PassengerId  SibSp  Parch   Age Cabin
# 868          869      0      0  42.0   NaN
# Number of passengers with family survival information: 420

# %%
data.loc[data['Family_Survival'] ==1]
# Out:
#        Age        Cabin Embarked      Fare  \
# 8    27.00          NaN        S   11.1333
# 10    4.00           G6        S   16.7000
# 25   38.00          NaN        S   31.3875
# 27   19.00  C23 C25 C27        S  263.0000
# 34   28.00          NaN        C   82.1708
# 35   42.00          NaN        S   52.0000
# 39   14.00          NaN        C   11.2417
# 43    3.00          NaN        C   41.5792
# 52   49.00          D33        C   76.7292
# 58    5.00          NaN        S   27.7500
# 62   45.00          C83        S   83.4750
# 65    6.00          NaN        C   15.2458
# 78    0.83          NaN        S   29.0000
# 88   23.00  C23 C25 C27        S  263.0000
# 93   26.00          NaN        S   20.5750
# 98   34.00          NaN        S   23.0000
# 99   34.00          NaN        S   26.0000
# 118  24.00      B58 B60        C  247.5208
# 122  32.50          NaN        C   30.0708
# 125  12.00          NaN        C   11.2417
# 128   9.00        F E69        C   22.3583
# 137  37.00         C123        S   53.1000
# 148  36.50           F2        S   26.0000
# 165   9.00          NaN        S   20.5250
# 172   1.00          NaN        S   11.1333
# 182   9.00          NaN        S   31.3875
# 183   1.00           F4        S   39.0000
# 193   3.00           F2        S   26.0000
# 206  32.00          NaN        S   15.8500
# 215  31.00          D36        C  113.2750
# ..     ...          ...      ...       ...
# 262  29.00          NaN        S   23.0000
# 277  40.00          NaN        S   26.0000
# 283   9.00          NaN        C   15.2458
# 293  53.00          A34        S   81.8583
# 296   1.00          NaN        C   41.5792
# 306  30.00      C22 C26        S  151.5500
# 307   0.83          NaN        S    9.3500
# 308  55.00          B69        S   93.5000
# 313  37.00          NaN        Q    7.7500
# 316  57.00          B78        C  146.5208
# 318  27.00          NaN        S    7.8542
# 326  12.00           F4        S   39.0000
# 328  29.00          NaN        S   26.0000
# 330  48.00          NaN        S   36.7500
# 333  19.00          NaN        C   15.7417
# 343  58.00  B51 B53 B55        C  512.3292
# 350  45.00      D10 D12        C   63.3583
# 353  49.00          NaN        S   65.0000
# 354   0.17          NaN        S   20.5750
# 361  24.00          NaN        C   37.0042
# 364  25.00          E50        C   55.4417
# 374  54.00          A34        S   81.8583
# 379   5.00          NaN        S   31.3875
# 385  24.00          NaN        S   65.0000
# 391  51.00          D28        S   39.4000
# 392  13.00          NaN        S   20.2500
# 394  29.00          NaN        S   22.0250
# 397  48.00          B41        C   79.2000
# 411  37.00          C78        Q   90.0000
# 417   6.00          NaN        C   22.3583
#
#                                                   Name  Parch  PassengerId  \
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2            9
# 10                     Sandstrom, Miss. Marguerite Rut      1           11
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5           26
# 27                      Fortune, Mr. Charles Alexander      2           28
# 34                             Meyer, Mr. Edgar Joseph      0           35
# 35                      Holverson, Mr. Alexander Oskar      0           36
# 39                         Nicola-Yarred, Miss. Jamila      0           40
# 43            Laroche, Miss. Simonne Marie Anne Andree      2           44
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)      0           53
# 58                        West, Miss. Constance Mirium      2           59
# 62                         Harris, Mr. Henry Birkhardt      0           63
# 65                            Moubarek, Master. Gerios      1           66
# 78                       Caldwell, Master. Alden Gates      2           79
# 88                          Fortune, Miss. Mabel Helen      2           89
# 93                             Dean, Mr. Bertram Frank      2           94
# 98                Doling, Mrs. John T (Ada Julia Bone)      1           99
# 99                                   Kantor, Mr. Sinai      0          100
# 118                           Baxter, Mr. Quigg Edmond      1          119
# 122                               Nasser, Mr. Nicholas      0          123
# 125                       Nicola-Yarred, Master. Elias      0          126
# 128                                  Peter, Miss. Anna      1          129
# 137                        Futrelle, Mr. Jacques Heath      0          138
# 148           Navratil, Mr. Michel ("Louis M Hoffman")      2          149
# 165    Goldsmith, Master. Frank John William "Frankie"      2          166
# 172                       Johnson, Miss. Eleanor Ileen      1          173
# 182              Asplund, Master. Clarence Gustaf Hugo      2          183
# 183                          Becker, Master. Richard F      1          184
# 193                         Navratil, Master. Michel M      1          194
# 206                         Backstrom, Mr. Karl Alfred      0          207
# 215                            Newell, Miss. Madeleine      0          216
# ..                                                 ...    ...          ...
# 262  Wells, Mrs. Arthur Henry (Addie" Dart Trevaskis)"      2         1154
# 277                              Faunthorpe, Mr. Harry      0         1169
# 283                         Touma, Miss. Maria Youssef      1         1175
# 293                              Dodge, Dr. Washington      1         1185
# 296                              Laroche, Miss. Louise      2         1188
# 306               Allison, Mr. Hudson Joshua Creighton      2         1198
# 307                          Aks, Master. Philip Frank      1         1199
# 308                         Hays, Mr. Charles Melville      1         1200
# 313                                Carr, Miss. Jeannie      0         1205
# 316                      Spencer, Mr. William Augustus      0         1208
# 318                          Jonsson, Mr. Nils Hilding      0         1210
# 326                       Becker, Miss. Ruth Elizabeth      1         1218
# 328                      Clarke, Mr. Charles Valentine      0         1220
# 330  Davies, Mrs. John Morgan (Elizabeth Agnes Mary...      2         1222
# 333              Nakid, Mrs. Said (Waika Mary" Mowad)"      1         1225
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...      1         1235
# 350       Greenfield, Mrs. Leo David (Blanche Strouse)      1         1242
# 353                                 Herman, Mr. Samuel      2         1245
# 354            Dean, Miss. Elizabeth Gladys Millvina""      2         1246
# 361            Mallet, Mrs. Albert (Antoinette Magnin)      1         1253
# 364       Harder, Mrs. George Achilles (Dorothy Annan)      0         1256
# 374              Dodge, Mrs. Washington (Ruth Vidaver)      1         1266
# 379                        Asplund, Master. Carl Edgar      2         1271
# 385                                 Herman, Miss. Kate      2         1277
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1         1283
# 392                      Abbott, Master. Eugene Joseph      2         1284
# 394                           Kink-Heilmann, Mr. Anton      1         1286
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1         1289
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)      0         1303
# 417                           Peter, Master. Michael J      1         1309
#
#      Pclass  Sex  SibSp       ...         Peers max  Group    per_fare  \
# 8         3    0      0       ...             3   3    1.0    3.711100
# 10        3    0      1       ...             3   3    1.0    5.566667
# 25        3    0      1       ...             7   7    1.0    4.483929
# 27        1    1      3       ...             6   6    1.0   43.833333
# 34        1    1      1       ...             2   2    1.0   41.085400
# 35        1    1      1       ...             2   2    1.0   26.000000
# 39        3    0      1       ...             2   2    1.0    5.620850
# 43        2    0      1       ...             4   4    1.0   10.394800
# 52        1    0      1       ...             3   2    1.0   38.364600
# 58        2    0      1       ...             4   4    1.0    6.937500
# 62        1    1      1       ...             2   2    1.0   41.737500
# 65        3    1      1       ...             3   3    1.0    5.081933
# 78        2    1      0       ...             3   3    1.0    9.666667
# 88        1    0      3       ...             6   6    1.0   43.833333
# 93        3    1      1       ...             4   4    1.0    5.143750
# 98        2    0      0       ...             2   2    1.0   11.500000
# 99        2    1      1       ...             2   2    1.0   13.000000
# 118       1    1      0       ...             3   3    0.0   82.506933
# 122       2    1      1       ...             2   2    1.0   15.035400
# 125       3    1      1       ...             2   2    1.0    5.620850
# 128       3    0      1       ...             3   3    1.0    7.452767
# 137       1    1      1       ...             2   2    1.0   26.550000
# 148       2    1      0       ...             3   3    1.0    8.666667
# 165       3    1      0       ...             3   3    1.0    6.841667
# 172       3    0      1       ...             3   3    1.0    3.711100
# 182       3    1      4       ...             7   7    1.0    4.483929
# 183       2    1      2       ...             4   4    1.0    9.750000
# 193       2    1      1       ...             3   3    1.0    8.666667
# 206       3    1      1       ...             2   4    0.0    3.962500
# 215       1    0      1       ...             3   3    0.0   37.758333
# ..      ...  ...    ...       ...           ...  ..    ...         ...
# 262       2    0      0       ...             3   3    1.0    7.666667
# 277       2    1      1       ...             2   2    1.0   13.000000
# 283       3    0      1       ...             3   3    1.0    5.081933
# 293       1    1      1       ...             3   3    1.0   27.286100
# 296       2    0      1       ...             4   4    1.0   10.394800
# 306       1    1      1       ...             6   4    1.0   37.887500
# 307       3    1      0       ...             2   2    1.0    4.675000
# 308       1    1      1       ...             4   3    1.0   31.166667
# 313       3    0      0       ...             1   1    1.0    7.750000
# 316       1    1      1       ...             3   2    1.0   73.260400
# 318       3    1      0       ...             1   1    1.0    7.854200
# 326       2    0      2       ...             4   4    1.0    9.750000
# 328       2    1      1       ...             2   2    1.0   13.000000
# 330       2    0      0       ...             4   3    1.0   12.250000
# 333       3    0      1       ...             3   3    1.0    5.247233
# 343       1    0      0       ...             4   2    1.0  256.164600
# 350       1    0      0       ...             2   2    1.0   31.679150
# 353       2    1      1       ...             5   4    1.0   16.250000
# 354       3    0      1       ...             4   4    1.0    5.143750
# 361       2    0      1       ...             3   3    1.0   12.334733
# 364       1    0      1       ...             2   2    1.0   27.720850
# 374       1    0      1       ...             3   3    1.0   27.286100
# 379       3    1      4       ...             7   7    1.0    4.483929
# 385       2    0      1       ...             5   4    1.0   16.250000
# 391       1    0      0       ...             2   2    1.0   19.700000
# 392       3    1      0       ...             3   3    1.0    6.750000
# 394       3    1      3       ...             3   5    1.0    4.405000
# 397       1    0      1       ...             2   3    1.0   26.400000
# 411       1    0      1       ...             3   3    0.0   30.000000
# 417       3    1      1       ...             3   3    1.0    7.452767
#
#                FareBin  FareBin_Code  Age_type  Name_length         Last_name  \
# 8       (10.5, 21.558]             2         3           49           Johnson
# 10      (10.5, 21.558]             2         1           31         Sandstrom
# 25    (21.558, 41.579]             3         3           57           Asplund
# 27   (41.579, 512.329]             4         2           30           Fortune
# 34   (41.579, 512.329]             4         3           23             Meyer
# 35   (41.579, 512.329]             4         3           30         Holverson
# 39      (10.5, 21.558]             2         2           27     Nicola-Yarred
# 43    (21.558, 41.579]             3         1           40           Laroche
# 52   (41.579, 512.329]             4         3           40            Harper
# 58    (21.558, 41.579]             3         1           28              West
# 62   (41.579, 512.329]             4         3           27            Harris
# 65      (10.5, 21.558]             2         1           24          Moubarek
# 78    (21.558, 41.579]             3         1           29          Caldwell
# 88   (41.579, 512.329]             4         3           26           Fortune
# 93      (10.5, 21.558]             2         3           23              Dean
# 98    (21.558, 41.579]             3         3           36            Doling
# 99    (21.558, 41.579]             3         3           17            Kantor
# 118  (41.579, 512.329]             4         3           24            Baxter
# 122   (21.558, 41.579]             3         3           20            Nasser
# 125     (10.5, 21.558]             2         2           28     Nicola-Yarred
# 128   (21.558, 41.579]             3         2           17             Peter
# 137  (41.579, 512.329]             4         3           27          Futrelle
# 148   (21.558, 41.579]             3         3           40          Navratil
# 165     (10.5, 21.558]             2         2           47         Goldsmith
# 172     (10.5, 21.558]             2         1           28           Johnson
# 182   (21.558, 41.579]             3         2           37           Asplund
# 183   (21.558, 41.579]             3         1           25            Becker
# 193   (21.558, 41.579]             3         1           26          Navratil
# 206     (10.5, 21.558]             2         3           26         Backstrom
# 215  (41.579, 512.329]             4         3           23            Newell
# ..                 ...           ...       ...          ...               ...
# 262   (21.558, 41.579]             3         3           49             Wells
# 277   (21.558, 41.579]             3         3           21        Faunthorpe
# 283     (10.5, 21.558]             2         2           26             Touma
# 293  (41.579, 512.329]             4         4           21             Dodge
# 296   (21.558, 41.579]             3         1           21           Laroche
# 306  (41.579, 512.329]             4         3           36           Allison
# 307      (7.854, 10.5]             1         1           25               Aks
# 308  (41.579, 512.329]             4         4           26              Hays
# 313    (-0.001, 7.854]             0         3           19              Carr
# 316  (41.579, 512.329]             4         4           29           Spencer
# 318    (-0.001, 7.854]             0         3           25           Jonsson
# 326   (21.558, 41.579]             3         2           28            Becker
# 328   (21.558, 41.579]             3         3           29            Clarke
# 330   (21.558, 41.579]             3         3           54            Davies
# 333     (10.5, 21.558]             2         2           37             Nakid
# 343  (41.579, 512.329]             4         4           63           Cardeza
# 350  (41.579, 512.329]             4         3           44        Greenfield
# 353  (41.579, 512.329]             4         3           18            Herman
# 354     (10.5, 21.558]             2         1           39              Dean
# 361   (21.558, 41.579]             3         3           39            Mallet
# 364  (41.579, 512.329]             4         3           44            Harder
# 374  (41.579, 512.329]             4         4           37             Dodge
# 379   (21.558, 41.579]             3         1           27           Asplund
# 385  (41.579, 512.329]             4         3           18            Herman
# 391   (21.558, 41.579]             3         4           46             Lines
# 392     (10.5, 21.558]             2         2           29            Abbott
# 394   (21.558, 41.579]             3         3           24     Kink-Heilmann
# 397  (41.579, 512.329]             4         3           63  Frolicher-Stehli
# 411  (41.579, 512.329]             4         3           47           Minahan
# 417   (21.558, 41.579]             3         1           24             Peter
#
#      Family_Survival
# 8                1.0
# 10               1.0
# 25               1.0
# 27               1.0
# 34               1.0
# 35               1.0
# 39               1.0
# 43               1.0
# 52               1.0
# 58               1.0
# 62               1.0
# 65               1.0
# 78               1.0
# 88               1.0
# 93               1.0
# 98               1.0
# 99               1.0
# 118              1.0
# 122              1.0
# 125              1.0
# 128              1.0
# 137              1.0
# 148              1.0
# 165              1.0
# 172              1.0
# 182              1.0
# 183              1.0
# 193              1.0
# 206              1.0
# 215              1.0
# ..               ...
# 262              1.0
# 277              1.0
# 283              1.0
# 293              1.0
# 296              1.0
# 306              1.0
# 307              1.0
# 308              1.0
# 313              1.0
# 316              1.0
# 318              1.0
# 326              1.0
# 328              1.0
# 330              1.0
# 333              1.0
# 343              1.0
# 350              1.0
# 353              1.0
# 354              1.0
# 361              1.0
# 364              1.0
# 374              1.0
# 379              1.0
# 385              1.0
# 391              1.0
# 392              1.0
# 394              1.0
# 397              1.0
# 411              1.0
# 417              1.0
#
# [218 rows x 27 columns]

# %%
sns.heatmap(data.iloc[:int(data_train.shape[0])].corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
temp = data.iloc[:int(data_train.shape[0])].copy()
temp["Survived"][temp["Survived"]==1] = 'Survived'
temp["Survived"][temp["Survived"]==0] = 'Died'

g = sns.pairplot(temp[[u'Pclass',u'Sex',u'Surname',u'Age'  , u'Parch',  u'FamilySize',  u'Survived',u'Peers',u'Group',u'Name_length',u'Cabin_type']], hue='Survived', palette = 'seismic',size=1.2,diag_kind = 'kde',diag_kws=dict(shade=True),plot_kws=dict(s=10) )
g.set(xticklabels=[])

# %%
temp = data.iloc[:int(data_train.shape[0])].copy()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn import clone
from sklearn import utils
from sklearn import model_selection
from sklearn import metrics
from sklearn import svm

from sklearn import neighbors
from sklearn import gaussian_process
from sklearn import ensemble
from sklearn import naive_bayes 
from sklearn import discriminant_analysis
from sklearn import linear_model
from sklearn import tree
from sklearn.metrics import confusion_matrix
from brew.base import Ensemble, EnsembleClassifier
from brew.stacking.stacker import EnsembleStack, EnsembleStackClassifier
from brew.combination.combiner import Combiner

from xgboost import XGBRegressor
from xgboost import XGBClassifier
import math

# %%
"""
cal = ['Sex','Family_Survival','per_fare','FamilySize','Age_type','FareBin_Code']

data_n_age= temp.loc[(temp['Age'] == 0)]
data_age1=temp.loc[(temp['Age']>=1)]

data_age2 = data_age1.copy()
data_age = data_age1.append(data_n_age)


train_x_age,test_x_age =model_selection.train_test_split(data_age2[cal],random_state = 42)




def sqrt(x):
     return math.sqrt(x)

    
  
train_x_age,test_x_age =model_selection.train_test_split(data_age1[cal],random_state = 42)
#data_age1['Age'] = data_age1['Age'].apply(sqrt)
data_age1['Age'] = data_age1['Age'].astype(int)
print(utils.multiclass.type_of_target(data_age1['Age']))
print(utils.multiclass.type_of_target(data_age1['Age'].astype('int')))

print("Data Shape: {}".format(temp.shape))
print( "No Data Shape: {}".format(data_n_age[cal].shape)) 
print( "Shape: {}".format(data_age1[cal].shape)) 
    
print("Train1 Shape: {}".format(train_x_age.shape))
print("Test1 Shape: {}".format(test_x_age.shape))
"""
# Out:
# '\ndata_n_age= temp.loc[(temp[\'Age\'] == 0)]\ndata_age1=temp.loc[(temp[\'Age\']>=1)]\n\ndata_age2 = data_age1.copy()\ndata_age = data_age1.append(data_n_age)\n\n\ntrain_x_age,test_x_age =model_selection.train_test_split(data_age2[cal],random_state = 42)\n\n\n\n\ndef sqrt(x):\n     return math.sqrt(x)\n\n    \n  \ntrain_x_age,test_x_age =model_selection.train_test_split(data_age1[cal],random_state = 42)\n#data_age1[\'Age\'] = data_age1[\'Age\'].apply(sqrt)\ndata_age1[\'Age\'] = data_age1[\'Age\'].astype(int)\nprint(utils.multiclass.type_of_target(data_age1[\'Age\']))\nprint(utils.multiclass.type_of_target(data_age1[\'Age\'].astype(\'int\')))\n\nprint("Data Shape: {}".format(temp.shape))\nprint( "No Data Shape: {}".format(data_n_age[cal].shape)) \nprint( "Shape: {}".format(data_age1[cal].shape)) \n    \nprint("Train1 Shape: {}".format(train_x_age.shape))\nprint("Test1 Shape: {}".format(test_x_age.shape))\n'

# %%
#pd.crosstab(data_n_age['Pclass'],data_n_age['Survived'],margins = True)

# %%
#pd.crosstab([data_n_age['Pclass'],data_n_age['Initial']],data_n_age['Survived'],margins = True)

# %%
#data_n_age.loc[(temp["Initial"] == 2)].head()

# %%
#test_x_age.head()

# %%
#data_age1.head()

# %%
temp['per_fare'] = temp['per_fare'].astype(int)

# %%
cal = ['Sex','Family_Survival','FamilySize','Age_type','FareBin_Code','Pclass']
train,test=train_test_split(temp[cal],test_size=0.3,random_state=0,stratify=temp['Survived'])
train_X=train[train.columns[1:]]
train_Y=train[train.columns[:1]]
test_X=test[test.columns[1:]]
test_Y=test[test.columns[:1]]
X=temp[cal]
Y=temp['Survived']

# %%
temp['Survived'].head()
# Out:
# 0    0.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.0
# Name: Survived, dtype: float64

# %%
X.head(30)
# Out:
#     Sex  Family_Survival  FamilySize  Age_type  FareBin_Code  Pclass
# 0     1              0.5           2         3             0       3
# 1     0              0.5           2         3             4       1
# 2     0              0.5           1         3             1       3
# 3     0              0.0           2         3             4       1
# 4     1              0.5           1         3             1       3
# 5     1              0.5           1         3             1       3
# 6     1              0.5           1         4             4       1
# 7     1              0.0           5         1             2       3
# 8     0              1.0           3         3             2       3
# 9     0              0.0           2         2             3       2
# 10    0              1.0           3         1             2       3
# 11    0              0.5           1         4             3       1
# 12    1              0.5           1         3             1       3
# 13    1              0.0           7         3             3       3
# 14    0              0.5           1         2             0       3
# 15    0              0.5           1         4             2       2
# 16    1              0.0           6         1             3       3
# 17    1              0.5           1         3             2       2
# 18    0              0.0           2         3             2       3
# 19    0              0.5           1         3             0       3
# 20    1              0.5           1         3             3       2
# 21    1              0.5           1         3             2       2
# 22    0              0.5           1         2             1       3
# 23    1              0.5           1         3             3       1
# 24    0              0.0           5         2             2       3
# 25    0              1.0           7         3             3       3
# 26    1              0.5           1         3             0       3
# 27    1              1.0           6         2             4       1
# 28    0              0.5           1         2             1       3
# 29    1              0.5           1         3             1       3

# %%
MLR = [
    
    linear_model.LinearRegression(),

    linear_model.BayesianRidge(),
    
    #linear_model.SGDRegressor(),
    #Ensemble Methods
    ensemble.AdaBoostRegressor(),
    ensemble.GradientBoostingRegressor(), 
    ensemble.RandomForestRegressor(),
    ensemble.ExtraTreesRegressor(),
    #Gaussian Processes
  
    
    #GLM
    


    
    
    #Navies Bayes
    
    
    #Nearest Neighbor
    neighbors.KNeighborsRegressor(),
    
    #SVM
    svm.SVR(),
    
    #Trees    
    tree.DecisionTreeRegressor(),
    #Discriminant Analysis
    

    
    #xgboost: http://xgboost.readthedocs.io/en/latest/model.html
    XGBRegressor()    
    ]

# %%
MLA = [
    #Ensemble Methods
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(),
    ensemble.ExtraTreesClassifier(),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(),

    #Gaussian Processes
    gaussian_process.GaussianProcessClassifier(),
    
    #GLM
    linear_model.LogisticRegressionCV(),
    linear_model.PassiveAggressiveClassifier(),
    linear_model.RidgeClassifierCV(),
    linear_model.SGDClassifier(),
    linear_model.Perceptron(),
    
    #Navies Bayes
    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),
    
    #Nearest Neighbor
    neighbors.KNeighborsClassifier(),
    
    #SVM
    svm.SVC(probability=True),
    svm.NuSVC(probability=True),
    svm.LinearSVC(),
    
    #Trees    
    tree.DecisionTreeClassifier(),
    tree.ExtraTreeClassifier(),
    
    #Discriminant Analysis
    discriminant_analysis.LinearDiscriminantAnalysis(),
    discriminant_analysis.QuadraticDiscriminantAnalysis(),

    
    #xgboost: http://xgboost.readthedocs.io/en/latest/model.html
    XGBClassifier()    
    ]

# %%
cv_split = model_selection.ShuffleSplit(n_splits = 10, test_size =.3, train_size = .6 ,random_state = 42)
kf = model_selection.KFold(n_splits= 5, random_state = 42)
#create table to compare MLA metrics
MLA_columns = ['MLA Name','MLA Parameters','MLA Train Accuracy Mean',' MLA Test Accuracy Mean','MLA Test Accuracy 3* STD','MLA Time']
MLA_compare = pd.DataFrame(columns = MLA_columns)
Target = ['Survived']
#create table to compare MLA predictions
MLA_predict = temp[Target]

row_index = 0
 
for alg in MLA:
    #set name and parameters
    MLA_name = alg.__class__.__name__
    MLA_compare.loc[row_index, 'MLA Name'] = MLA_name
    MLA_compare.loc[row_index, 'MLA Parameters'] = str(alg.get_params())
    
    cv_results = model_selection.cross_validate(alg, temp[cal],temp[Target], cv = 5)
    
    MLA_compare.loc[row_index, 'MLA Time'] = cv_results['fit_time'].mean()
    MLA_compare.loc[row_index, 'MLA Train Accuracy Mean'] = cv_results['train_score'].mean()
    MLA_compare.loc[row_index, 'MLA Test Accuracy Mean'] = cv_results['test_score'].mean()   
    #if this is a non-bias random sample, then +/-3 standard deviations (std) from the mean, should statistically capture 99.7% of the subsets
    MLA_compare.loc[row_index, 'MLA Test Accuracy 3*STD'] = cv_results['test_score'].std()*3   #let's know the worst that can happen!
    
    
    #Save MLA predictions - see section 6 for usage
    alg.fit(temp[cal],temp[Target])
    MLA_predict[MLA_name] = alg.predict(temp[cal])
    row_index+=1
MLA_compare.sort_values(by = ['MLA Test Accuracy Mean'], ascending = False, inplace = True)
MLA_compare
# Out:
#                          MLA Name  \
# 21                  XGBClassifier
# 14                            SVC
# 3      GradientBoostingClassifier
# 16                      LinearSVC
# 1               BaggingClassifier
# 19     LinearDiscriminantAnalysis
# 8               RidgeClassifierCV
# 15                          NuSVC
# 0              AdaBoostClassifier
# 4          RandomForestClassifier
# 6            LogisticRegressionCV
# 2            ExtraTreesClassifier
# 5       GaussianProcessClassifier
# 17         DecisionTreeClassifier
# 18            ExtraTreeClassifier
# 20  QuadraticDiscriminantAnalysis
# 13           KNeighborsClassifier
# 11                    BernoulliNB
# 12                     GaussianNB
# 7     PassiveAggressiveClassifier
# 9                   SGDClassifier
# 10                     Perceptron
#
#                                        MLA Parameters MLA Train Accuracy Mean  \
# 21  {'base_score': 0.5, 'booster': 'gbtree', 'cols...                0.856903
# 14  {'C': 1.0, 'cache_size': 200, 'class_weight': ...                0.845117
# 3   {'criterion': 'friedman_mse', 'init': None, 'l...                0.868129
# 16  {'C': 1.0, 'class_weight': None, 'dual': True,...                0.832494
# 1   {'base_estimator': None, 'bootstrap': True, 'b...                 0.88328
# 19  {'n_components': None, 'priors': None, 'shrink...                0.827163
# 8   {'alphas': (0.1, 1.0, 10.0), 'class_weight': N...                0.826883
# 15  {'cache_size': 200, 'class_weight': None, 'coe...                0.836422
# 0   {'algorithm': 'SAMME.R', 'base_estimator': Non...                0.831647
# 4   {'bootstrap': True, 'class_weight': None, 'cri...                0.882441
# 6   {'Cs': 10, 'class_weight': None, 'cv': None, '...                0.829126
# 2   {'bootstrap': False, 'class_weight': None, 'cr...                0.885526
# 5   {'copy_X_train': True, 'kernel': None, 'max_it...                 0.86336
# 17  {'class_weight': None, 'criterion': 'gini', 'm...                0.885526
# 18  {'class_weight': None, 'criterion': 'gini', 'm...                0.885526
# 20  {'priors': None, 'reg_param': 0.0, 'store_cova...                0.817616
# 13  {'algorithm': 'auto', 'leaf_size': 30, 'metric...                0.849335
# 11  {'alpha': 1.0, 'binarize': 0.0, 'class_prior':...                0.787876
# 12                                   {'priors': None}                0.793769
# 7   {'C': 1.0, 'average': False, 'class_weight': N...                0.772725
# 9   {'alpha': 0.0001, 'average': False, 'class_wei...                0.765512
# 10  {'alpha': 0.0001, 'class_weight': None, 'eta0'...                0.651145
#
#     MLA Test Accuracy Mean MLA Test Accuracy 3* STD    MLA Time  \
# 21                     NaN                      NaN   0.0153833
# 14                     NaN                      NaN   0.0429144
# 3                      NaN                      NaN   0.0540327
# 16                     NaN                      NaN   0.0253737
# 1                      NaN                      NaN   0.0115605
# 19                     NaN                      NaN  0.00171113
# 8                      NaN                      NaN  0.00372772
# 15                     NaN                      NaN   0.0540934
# 0                      NaN                      NaN   0.0544616
# 4                      NaN                      NaN    0.011454
# 6                      NaN                      NaN   0.0787596
# 2                      NaN                      NaN   0.0120283
# 5                      NaN                      NaN    0.209958
# 17                     NaN                      NaN  0.00151491
# 18                     NaN                      NaN  0.00142484
# 20                     NaN                      NaN  0.00141459
# 13                     NaN                      NaN  0.00160704
# 11                     NaN                      NaN  0.00153098
# 12                     NaN                      NaN   0.0014143
# 7                      NaN                      NaN  0.00150313
# 9                      NaN                      NaN  0.00147815
# 10                     NaN                      NaN  0.00147099
#
#     MLA Test Accuracy Mean  MLA Test Accuracy 3*STD
# 21                0.839512                 0.034370
# 14                0.838389                 0.040206
# 3                 0.832827                 0.056275
# 16                0.832815                 0.045572
# 1                 0.829456                 0.075306
# 19                0.829450                 0.045669
# 8                 0.828327                 0.041828
# 15                0.828314                 0.054222
# 0                 0.828308                 0.038237
# 4                 0.824962                 0.060157
# 6                 0.823826                 0.044819
# 2                 0.819356                 0.059087
# 5                 0.818277                 0.072814
# 17                0.812640                 0.081306
# 18                0.811491                 0.065821
# 20                0.810405                 0.071382
# 13                0.808139                 0.047052
# 11                0.787839                 0.057001
# 12                0.784657                 0.105248
# 7                 0.769987                 0.142040
# 9                 0.729309                 0.220388
# 10                0.643497                 0.340776

# %%
from sklearn.model_selection import cross_val_score #score evaluation
from sklearn.model_selection import cross_val_predict #prediction
xyz=[]
accuracy=[]
std=[]

classifiers=['Ada','Bagging','Extra','Gradiet','Random','Gaussian','LogisticRCV','PassiveAgg','Ridge','SGD','Perceptron','Bernoulli',
             'GaussianNB','KNeighbor','SVC','NuSVC','LinearSVC','Decision','Extra','LinearDiscriminant','Quadratic','XGB']
for i in MLA:
    model = i
    cv_result = model_selection.cross_val_score(model,X,Y, cv = kf,scoring = "accuracy")
    cv_result = cv_result
    xyz.append(cv_result.mean())
    std.append(cv_result.std())
    accuracy.append(cv_result)
new_models_dataframe2=pd.DataFrame({'CV Mean':xyz,'Std':std},index=classifiers)       
new_models_dataframe2
# Out:
#                      CV Mean       Std
# Ada                 0.823796  0.017589
# Bagging             0.824933  0.029058
# Extra               0.819308  0.017860
# Gradiet             0.832779  0.021082
# Random              0.822679  0.022005
# Gaussian            0.820438  0.020911
# LogisticRCV         0.827180  0.019721
# PassiveAgg          0.704771  0.135053
# Ridge               0.830544  0.020687
# SGD                 0.662055  0.149983
# Perceptron          0.702492  0.115412
# Bernoulli           0.787848  0.027591
# GaussianNB          0.789084  0.041408
# KNeighbor           0.818197  0.015531
# SVC                 0.837236  0.021778
# NuSVC               0.828272  0.026078
# LinearSVC           0.833902  0.018925
# Decision            0.815950  0.022468
# Extra               0.821555  0.025422
# LinearDiscriminant  0.830544  0.020687
# Quadratic           0.807005  0.024831
# XGB                 0.841749  0.022314

# %%
new_models_dataframe2['CV Mean'].plot.barh(width=0.8)
plt.title('Average CV Mean Accuracy')
fig=plt.gcf()
fig.set_size_inches(8,5)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(15,12))
model=ensemble.RandomForestClassifier(n_estimators=500,random_state=0)
model.fit(X,Y)
pd.Series(model.feature_importances_,X.columns).sort_values(ascending=True).plot.barh(width=0.8,ax=ax[0,0])
ax[0,0].set_title('Feature Importance in Random Forests')
model=ensemble.AdaBoostClassifier(n_estimators=200,learning_rate=0.05,random_state=0)
model.fit(X,Y)
pd.Series(model.feature_importances_,X.columns).sort_values(ascending=True).plot.barh(width=0.8,ax=ax[0,1],color='#ddff11')
ax[0,1].set_title('Feature Importance in AdaBoost')
model=ensemble.GradientBoostingClassifier(n_estimators=500,learning_rate=0.1,random_state=0)
model.fit(X,Y)
pd.Series(model.feature_importances_,X.columns).sort_values(ascending=True).plot.barh(width=0.8,ax=ax[1,0],cmap='RdYlGn_r')
ax[1,0].set_title('Feature Importance in Gradient Boosting')
model=XGBClassifier(n_estimators=900,learning_rate=0.1)
model.fit(X,Y)
pd.Series(model.feature_importances_,X.columns).sort_values(ascending=True).plot.barh(width=0.8,ax=ax[1,1],color='#FD0F00')
ax[1,1].set_title('Feature Importance in XgBoost')

plt.show()

# %%
train_index = temp.shape[0]
real_test = data.iloc[int(train_index):]

real_test_X = real_test[cal]
real_test_Y = real_test['Survived']
#real_test_X['per_fare'] = real_test_X['per_fare'].fillna(0)
#real_test_X['per_fare'] = real_test_X['per_fare'].astype(int)
real_test_X.isnull().any()
# Out:
# Sex                False
# Family_Survival    False
# FamilySize         False
# Age_type           False
# FareBin_Code       False
# Pclass             False
# dtype: bool

# %%
n_neighbors = [6,7,8,9,10,11,12,14,16,18,20,22]
algorithm = ['auto']
weights = ['uniform', 'distance']
leaf_size = list(range(1,50,5))
hyperparams = {'algorithm': algorithm, 'weights': weights, 'leaf_size': leaf_size, 
               'n_neighbors': n_neighbors}
gd=GridSearchCV(estimator = neighbors.KNeighborsClassifier(), param_grid = hyperparams, verbose=True, 
                cv=10, scoring = "roc_auc",n_jobs =-1)
gd.fit(X, Y)
print(gd.best_score_)
print(gd.best_estimator_)
# Out:
# Fitting 10 folds for each of 240 candidates, totalling 2400 fits
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 1240 tasks      | elapsed:    4.0s
# 0.8742196920714118
# KNeighborsClassifier(algorithm='auto', leaf_size=6, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=7, p=2,
#            weights='uniform')
# [Parallel(n_jobs=-1)]: Done 2400 out of 2400 | elapsed:    6.6s finished

# %%
param_grid = { 
    'n_estimators': range(100,1000,100) ,'learning_rate' : [0.1,0.2,0.5,1,1.5,2],
     'max_depth': [3,4,5,6,None] }
grid_search =GridSearchCV(ensemble.GradientBoostingClassifier(),param_grid,cv = 10,n_jobs = -1)
grid_search.fit(X,Y)
print(grid_search.best_score_)
print(grid_search.best_estimator_)
# Out:
# 0.8372615039281706
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
param_grid = {"base_estimator__criterion" : ["gini", "entropy"],
              "base_estimator__splitter" :   ["best", "random"],
              'n_estimators': range(100,1000,100) ,'learning_rate' : [0.1,0.2,0.5,1,1.5,2]
             }


DTC = tree.DecisionTreeClassifier(random_state = 42, max_features = "auto", class_weight = None,max_depth = None)
grid_search =GridSearchCV(ensemble.AdaBoostClassifier(base_estimator = DTC),param_grid = param_grid,cv = kf,n_jobs = 10)
grid_search.fit(X,Y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=False),
#        error_score='raise',
#        estimator=AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None),
#        fit_params=None, iid=True, n_jobs=10,
#        param_grid={'base_estimator__criterion': ['gini', 'entropy'], 'base_estimator__splitter': ['best', 'random'], 'n_estimators': range(100, 1000, 100), 'learning_rate': [0.1, 0.2, 0.5, 1, 1.5, 2]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
ada=ensemble.AdaBoostClassifier(algorithm='SAMME.R',learning_rate=1.0, n_estimators=50, random_state=42)
          
fit_ada = ada.fit(X,Y)
predi_ada = ada.predict(real_test_X)
result=cross_val_score(ada,X,Y,cv=kf,scoring='accuracy')
print('The cross validated score for AdaBoost is:',result.mean())
predi_ada = predi_ada.astype(int)
# Out:
# The cross validated score for AdaBoost is: 0.8237963718536188

# %%
xgb =XGBClassifier()
fit_xgb = xgb.fit(X,Y)
predi_xgb = xgb.predict(real_test_X)
result = cross_val_score(xgb,X,Y,cv=5,scoring='accuracy')
print('The cross validated score for XGBoost is:',result.mean())
predi_xgb = predi_xgb.astype(int)

# %%
grad = ensemble.GradientBoostingClassifier(criterion='friedman_mse', init=None,
              learning_rate=0.1, loss='deviance', max_depth=3,
              max_features=None, max_leaf_nodes=None,
              min_impurity_decrease=0.0, min_impurity_split=None,
              min_samples_leaf=1, min_samples_split=2,
              min_weight_fraction_leaf=0.0, n_estimators=100,
              presort='auto', random_state=None, subsample=1.0, verbose=0,
              warm_start=False)
result = cross_val_score(grad,X,Y,cv = kf,scoring = "accuracy")
print('The cross validated score for Gradient:',result.mean())
# Out:
# The cross validated score for Gradient: 0.8327788588286988

# %%
qudra = discriminant_analysis.QuadraticDiscriminantAnalysis()
result = cross_val_score(qudra,X,Y,cv = kf,scoring = "accuracy")
print('The cross validated score for qudra:',result.mean())

# %%
dis = discriminant_analysis.LinearDiscriminantAnalysis()
result = cross_val_score(dis,X,Y,cv = kf,scoring = "accuracy")
print('The cross validated score for LinearDiscriminantAnalysis:',result.mean())

# %%
extra = ensemble.ExtraTreesClassifier()
result = cross_val_score(extra,X,Y,cv = kf,scoring = "accuracy")
print('The cross validated score for Extratree:',result.mean())

# %%
rid = linear_model.RidgeClassifierCV()
result =cross_val_score(rid,X,Y,cv = kf,scoring = 'accuracy')
print('The cross validated score for :',result.mean())

# %%
rand = ensemble.RandomForestClassifier(n_jobs = -1,max_depth = 8, max_features='sqrt')
            
result = cross_val_score(rand,X,Y, cv = kf, scoring = 'accuracy')
print("The cross validated score for RandomForest:", result.mean())

# %%
model = xgb.fit(X,Y)
y_test_pred  = model.predict(real_test_X)

# %%
grid_search.best_estimator_.fit(X, Y)
y_pred = grid_search.best_estimator_.predict(real_test_X)

# %%
y_pred = y_pred.astype(int)

# %%
emp = pd.DataFrame(pd.read_csv("input/test.csv")['PassengerId'])
emp['Survived'] =y_pred
emp.to_csv("original_submission.csv", index = False)

# %%
gaus = naive_bayes.GaussianNB()
result =cross_val_score(gaus,X,Y,cv = kf,scoring = 'accuracy')
print('The cross validated score for GaussianNB:',result.mean())

# %%
logi = linear_model.LogisticRegressionCV()
result = cross_val_score(logi,X,Y,cv = kf,scoring = 'accuracy')
print("The cross validated score for logistic",result.mean())

# %%
gausPC = gaussian_process.GaussianProcessClassifier()
result = cross_val_score(gausPC,X,Y,cv = kf,scoring = 'accuracy')
print('The cross validated score for GaussiaProcessClassifier:',result.mean())

# %%
nusvc = svm.NuSVC(probability=True)
result = cross_val_score(nusvc,X,Y,cv = kf,scoring = 'accuracy')
print('The cross validated score for NuSVC:',result.mean())

# %%
from vecstack import StackingTransformer
estimators = [('grad',grad) ,
              ('ada',ada),
             ('rand', rand),
             ('qudra',qudra)]
stack = StackingTransformer(estimators, regression=False, verbose=2)
stack = stack.fit(X, Y)

# %%
S_train = stack.transform(X)
S_test = stack.transform(real_test_X)

# %%
model = 
model = model.fit(S_train,Y)

y_test_pred = model.predict(S_test)
result =cross_val_score(xgb,S_train,Y,cv = kf,scoring = 'accuracy')
print('The cross validated score for XGB:',result.mean())

# %%
y_test_pred = y_test_pred.astype(int)

# %%
StackingSubmission = pd.DataFrame({ 'PassengerId': PassengerId,
                            'Survived': y_pred  })
StackingSubmission.to_csv("StackingSubmission.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-1ab621375e97> in <module>()
# ----> 1 StackingSubmission = pd.DataFrame({ 'PassengerId': PassengerId,
#       2                             'Survived': y_pred  })
#       3 StackingSubmission.to_csv("StackingSubmission.csv", index=False)
#
# NameError: name 'PassengerId' is not defined
